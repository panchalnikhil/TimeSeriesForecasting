# %% [markdown]
# __Problem Statement:__
#
# For this particular assignment, the data of different types of wine sales in the 20th century is to be analysed. Both of these data are from the same company but of different wines. As an analyst in the ABC Estate Wines, you are tasked to analyse and forecast Wine Sales in the 20th century.
#
# Dataset for the Problem: `'Rose.csv'`
#
# Please do perform the __following questions__ on each of these __two datasets separately__.
#
# 1. Read the data as an appropriate __Time Series data and plot the data__. (3 points)
# 2. Perform appropriate __Exploratory Data Analysis__ to understand the data and also __perform decomposition__. (4 points)
# 3. Split the data into __training and test__. The _test data should start in 1991_. (3 points)
# 4. Build various __exponential smoothing models__ on the training data and __evaluate the model using RMSE on the test data__. Other models such as __regression,naïve forecast models, simple average models etc.__ should also be built on the training data and check the performance on the test data using RMSE. (13 points)
# 5. Check for the __stationarity of the data__ on which the model is being built on using appropriate statistical tests and also mention the hypothesis for the statistical test. If the data is found __to be non-stationary, take appropriate steps to make it stationary__. Check the new data for stationarity and comment. Note: Stationarity should be checked at alpha = 0.05. (4 points)
# 6. Build an __automated version of the ARIMA/SARIMA model in which the parameters are selected using the lowest Akaike Information Criteria (AIC)__ on the training data and evaluate this model on the __test data using RMSE__. (7 points)
# 7. Build __ARIMA/SARIMA models based on the cut-off points of ACF and PACF__ on the training data and evaluate this model on the test data using RMSE. (6 points)
# 8. Build __a table with all the models built along with their corresponding parameters__ and the __respective RMSE values on the test data__. (3 points)
# 9. Based on __the model-building exercise__, build __the most optimum model(s) on the complete data and predict 12 months into the future with appropriate confidence intervals/bands__. (3 points)
# 10. Comment on __the model thus built and report your findings__ and __suggest the measures that the company should be taking for future sales__. (4 points)

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#LOAD-THE-DATASETS" data-toc-modified-id="LOAD-THE-DATASETS-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>LOAD THE DATASETS</a></span><ul class="toc-item"><li><span><a href="#Import-Libraries" data-toc-modified-id="Import-Libraries-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Import Libraries</a></span></li><li><span><a href="#Read-the-time-series-datasets-and-plot-the-graph" data-toc-modified-id="Read-the-time-series-datasets-and-plot-the-graph-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Read the time-series datasets and plot the graph</a></span></li></ul></li><li><span><a href="#Exploratory-Data-Analysis-&amp;-Decomposition" data-toc-modified-id="Exploratory-Data-Analysis-&amp;-Decomposition-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Exploratory Data Analysis &amp; Decomposition</a></span><ul class="toc-item"><li><span><a href="#Exploratory-Data-Analysis-(EDA)" data-toc-modified-id="Exploratory-Data-Analysis-(EDA)-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Exploratory Data Analysis (EDA)</a></span><ul class="toc-item"><li><span><a href="#Missing-data-check" data-toc-modified-id="Missing-data-check-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Missing data check</a></span></li><li><span><a href="#Basic-measure-of-Descriptive-Statistics" data-toc-modified-id="Basic-measure-of-Descriptive-Statistics-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Basic measure of Descriptive Statistics</a></span></li><li><span><a href="#Plot-a-year-on-year-boxplot" data-toc-modified-id="Plot-a-year-on-year-boxplot-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Plot a year on year boxplot</a></span></li><li><span><a href="#Plot-a-monthly-boxplot-by-taking-all-the-years-into-account" data-toc-modified-id="Plot-a-monthly-boxplot-by-taking-all-the-years-into-account-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Plot a monthly boxplot by taking all the years into account</a></span></li><li><span><a href="#Plot-a-monthplot-of-the-given-time-series" data-toc-modified-id="Plot-a-monthplot-of-the-given-time-series-2.1.5"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>Plot a monthplot of the given time series</a></span></li><li><span><a href="#Plot-the-Time-Series-according-to-different-months-for-different-years" data-toc-modified-id="Plot-the-Time-Series-according-to-different-months-for-different-years-2.1.6"><span class="toc-item-num">2.1.6&nbsp;&nbsp;</span>Plot the Time Series according to different months for different years</a></span></li><li><span><a href="#Lag-plot" data-toc-modified-id="Lag-plot-2.1.7"><span class="toc-item-num">2.1.7&nbsp;&nbsp;</span>Lag plot</a></span></li></ul></li><li><span><a href="#Decompose-the-Time-Series" data-toc-modified-id="Decompose-the-Time-Series-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Decompose the Time Series</a></span><ul class="toc-item"><li><span><a href="#Additive-Decomposition" data-toc-modified-id="Additive-Decomposition-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Additive Decomposition</a></span></li><li><span><a href="#Multiplicative-Decomposition" data-toc-modified-id="Multiplicative-Decomposition-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Multiplicative Decomposition</a></span></li></ul></li></ul></li><li><span><a href="#Train---Test-Split" data-toc-modified-id="Train---Test-Split-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Train - Test Split</a></span></li><li><span><a href="#Model-Building-using-various-Time-series-techniques" data-toc-modified-id="Model-Building-using-various-Time-series-techniques-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Model Building using various Time series techniques</a></span><ul class="toc-item"><li><span><a href="#Model-1:-Regression-on-Time" data-toc-modified-id="Model-1:-Regression-on-Time-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Model 1: Regression on Time</a></span></li><li><span><a href="#Model-2:-Regression-on-Time-With-Seasonal-Components" data-toc-modified-id="Model-2:-Regression-on-Time-With-Seasonal-Components-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Model 2: Regression on Time With Seasonal Components</a></span></li><li><span><a href="#Model-3:-Naive-Approach:--𝑦̂-𝑡+1=𝑦𝑡" data-toc-modified-id="Model-3:-Naive-Approach:--𝑦̂-𝑡+1=𝑦𝑡-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Model 3: Naive Approach:  𝑦̂ 𝑡+1=𝑦𝑡</a></span></li><li><span><a href="#Model-4:-Simple-Average" data-toc-modified-id="Model-4:-Simple-Average-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Model 4: Simple Average</a></span></li><li><span><a href="#Model-5:-Moving-Average(MA)" data-toc-modified-id="Model-5:-Moving-Average(MA)-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Model 5: Moving Average(MA)</a></span></li><li><span><a href="#Model-6:-Simple-Exponential-Smoothing-(SES)" data-toc-modified-id="Model-6:-Simple-Exponential-Smoothing-(SES)-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Model 6: Simple Exponential Smoothing (SES)</a></span></li><li><span><a href="#Model-7:-SES-model---Best-alpha-with-least-RMSE" data-toc-modified-id="Model-7:-SES-model---Best-alpha-with-least-RMSE-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Model 7: SES model - Best alpha with least RMSE</a></span></li><li><span><a href="#Model-8:-Holt's-Linear-Trend-Method-(Double-Exponential-Smoothing)" data-toc-modified-id="Model-8:-Holt's-Linear-Trend-Method-(Double-Exponential-Smoothing)-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Model 8: Holt's Linear Trend Method (Double Exponential Smoothing)</a></span></li><li><span><a href="#Model-9:-DES-model---Best-alpha-and-beta-with-least-RMSE" data-toc-modified-id="Model-9:-DES-model---Best-alpha-and-beta-with-least-RMSE-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Model 9: DES model - Best alpha and beta with least RMSE</a></span></li><li><span><a href="#Method-10:-Holt-Winters-Method---Additive-seasonality" data-toc-modified-id="Method-10:-Holt-Winters-Method---Additive-seasonality-4.10"><span class="toc-item-num">4.10&nbsp;&nbsp;</span>Method 10: Holt-Winters Method - Additive seasonality</a></span></li><li><span><a href="#Method-11:-Holt-Winters-Method---Multiplicative-seasonality" data-toc-modified-id="Method-11:-Holt-Winters-Method---Multiplicative-seasonality-4.11"><span class="toc-item-num">4.11&nbsp;&nbsp;</span>Method 11: Holt-Winters Method - Multiplicative seasonality</a></span></li></ul></li><li><span><a href="#Check-for-stationarity-on-Time-Series-data-(Full-data-&amp;-Train-data)." data-toc-modified-id="Check-for-stationarity-on-Time-Series-data-(Full-data-&amp;-Train-data).-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Check for stationarity on Time Series data (Full data &amp; Train data).</a></span><ul class="toc-item"><li><span><a href="#ADF-Test" data-toc-modified-id="ADF-Test-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>ADF Test</a></span></li><li><span><a href="#Convert-Non-stationary-to-Stationary" data-toc-modified-id="Convert-Non-stationary-to-Stationary-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Convert Non-stationary to Stationary</a></span></li></ul></li><li><span><a href="#Model-12-&amp;-13:-Automated-version-of-ARIMA-&amp;-SARIMA-model-with-least-AIC-(Akaike-Information-Criteria)-value" data-toc-modified-id="Model-12-&amp;-13:-Automated-version-of-ARIMA-&amp;-SARIMA-model-with-least-AIC-(Akaike-Information-Criteria)-value-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Model 12 &amp; 13: Automated version of ARIMA &amp; SARIMA model with least AIC (Akaike Information Criteria) value</a></span><ul class="toc-item"><li><span><a href="#ARIMA-Model" data-toc-modified-id="ARIMA-Model-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>ARIMA Model</a></span></li><li><span><a href="#SARIMA-Model" data-toc-modified-id="SARIMA-Model-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>SARIMA Model</a></span></li></ul></li><li><span><a href="#Model-14-&amp;-15:-ARIMA-&amp;-SARIMA-models-based-on-the-cut-off-points-of-ACF-&amp;-PACF" data-toc-modified-id="Model-14-&amp;-15:-ARIMA-&amp;-SARIMA-models-based-on-the-cut-off-points-of-ACF-&amp;-PACF-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Model 14 &amp; 15: ARIMA &amp; SARIMA models based on the cut-off points of ACF &amp; PACF</a></span><ul class="toc-item"><li><span><a href="#ACF-&amp;-PACF" data-toc-modified-id="ACF-&amp;-PACF-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>ACF &amp; PACF</a></span><ul class="toc-item"><li><span><a href="#Original-Series" data-toc-modified-id="Original-Series-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>Original Series</a></span></li><li><span><a href="#Differenced-Time-series-with-(d-=-1)" data-toc-modified-id="Differenced-Time-series-with-(d-=-1)-7.1.2"><span class="toc-item-num">7.1.2&nbsp;&nbsp;</span>Differenced Time series with (d = 1)</a></span></li></ul></li><li><span><a href="#ARIMA-Model" data-toc-modified-id="ARIMA-Model-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>ARIMA Model</a></span><ul class="toc-item"><li><span><a href="#ARIMA(2,1,2)" data-toc-modified-id="ARIMA(2,1,2)-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>ARIMA(2,1,2)</a></span></li><li><span><a href="#SARIMA-Model" data-toc-modified-id="SARIMA-Model-7.2.2"><span class="toc-item-num">7.2.2&nbsp;&nbsp;</span>SARIMA Model</a></span><ul class="toc-item"><li><span><a href="#ACF-and-PACF-(differenced-d-=-1)" data-toc-modified-id="ACF-and-PACF-(differenced-d-=-1)-7.2.2.1"><span class="toc-item-num">7.2.2.1&nbsp;&nbsp;</span>ACF and PACF (differenced d = 1)</a></span></li><li><span><a href="#ACF-and-PACF-Seasonal-differece(12)" data-toc-modified-id="ACF-and-PACF-Seasonal-differece(12)-7.2.2.2"><span class="toc-item-num">7.2.2.2&nbsp;&nbsp;</span>ACF and PACF Seasonal differece(12)</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Table-with-All-Models" data-toc-modified-id="Table-with-All-Models-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Table with All Models</a></span></li><li><span><a href="#Run-the-best-model-(Manual-SARIMA)-on-full-dataset-and-predict-12-months-into-the-future-with-appropriate-confidence-intervals/bands" data-toc-modified-id="Run-the-best-model-(Manual-SARIMA)-on-full-dataset-and-predict-12-months-into-the-future-with-appropriate-confidence-intervals/bands-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Run the best model (Manual SARIMA) on full dataset and predict 12 months into the future with appropriate confidence intervals/bands</a></span><ul class="toc-item"><li><span><a href="#Run-best-model-with-fulldata" data-toc-modified-id="Run-best-model-with-fulldata-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Run best model with fulldata</a></span></li><li><span><a href="#Forcest-for-next-12-months-with-confidence-intervals" data-toc-modified-id="Forcest-for-next-12-months-with-confidence-intervals-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Forcest for next 12 months with confidence intervals</a></span></li></ul></li><li><span><a href="#Comment-on-the-model-thus-built-and-report-your-findings-and-suggest-the-measures-that-the-company-should-be-taking-for-future-sales" data-toc-modified-id="Comment-on-the-model-thus-built-and-report-your-findings-and-suggest-the-measures-that-the-company-should-be-taking-for-future-sales-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Comment on the model thus built and report your findings and suggest the measures that the company should be taking for future sales</a></span><ul class="toc-item"><li><span><a href="#Key-Findings:" data-toc-modified-id="Key-Findings:-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Key Findings:</a></span></li><li><span><a href="#Business-Recommendations:" data-toc-modified-id="Business-Recommendations:-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>Business Recommendations:</a></span></li></ul></li></ul></div>

# %% [markdown]
# # LOAD THE DATASETS
#
# (Read the data as an appropriate Time Series data and plot the data)

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn import metrics


import statsmodels.api as sm
import statsmodels.tsa.api as smt
import statsmodels.formula.api as smf
from   sklearn.metrics   import mean_squared_error
from   math              import sqrt

import warnings
warnings.filterwarnings("ignore")

# %%
import  matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['axes.labelsize'] = 12
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %% [markdown]
# ## Read the time-series datasets and plot the graph

# %%
# load the dataset for "Rose"
df= pd.read_csv('Rose.csv',parse_dates=True,index_col=0)
df.head(2)
# Out:
#              Rose
# YearMonth
# 1980-01-01  112.0
# 1980-02-01  118.0

# %%
plt.rcParams["figure.figsize"] = (16,4)
# Plotting the time series for "Rose"
df.plot(color='black')
plt.title('Rose Wine: Time Series Plot')
plt.xlabel('Year')
plt.ylabel('Wine Sales: Rose')
plt.grid();

# %% [markdown]
# __Insights:__
#
# __Rose:__ By looking at the graph, It looks like:
#
# - There is __null values__ in the data. We will double check the same during EDA.
# - There is __promising trend and seasonality__ in the data.

# %% [markdown]
# # Exploratory Data Analysis & Decomposition
#
# Perform appropriate Exploratory Data Analysis to understand the data and also perform decomposition.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Missing data check

# %%
df.isnull().sum()
# Out:
# Rose    2
# dtype: int64

# %% [markdown]
# __Insights:__
#
# There is __2 null values__ in the dataset

# %%
# Plotting the time series for "Rose"
df.plot(color = 'red')
plt.title('Rose Wine: Time Series Plot (BEFORE imputaion)')
plt.xlabel('Year')
plt.ylabel('Wine Sales: Rose')
plt.grid();

#missing data imputation using "spline" interpolate method
df.interpolate(method = 'spline', order = 2,inplace=True)

# Plotting the time series for "Rose"
df.plot(color = 'blue')
plt.title('Rose Wine: Time Series Plot (AFTER spline impute method)')
plt.xlabel('Year')
plt.ylabel('Wine Sales: Rose')
plt.grid();

# %%
df.isnull().sum()
# Out:
# Rose    0
# dtype: int64

# %% [markdown]
# __Insights:__
#
# We have imputed __2 null records__ in `"Rose"` dataset, using __"spline" interpolate method__.

# %% [markdown]
# ### Basic measure of Descriptive Statistics

# %%
df.describe().T
# Out:
#       count       mean        std   min   25%   50%    75%    max
# Rose  187.0  89.908354  39.245313  28.0  62.5  85.0  111.0  267.0

# %%
df.skew()
# Out:
# Rose    1.266687
# dtype: float64

# %%
rollmean = df['Rose'].rolling(3).mean()
rollstd = df['Rose'].rolling(3).std()

# %%
original = plt.plot(df['Rose'], label='Original')
mean = plt.plot(rollmean, label='Rolling mean(3)')
std = plt.plot(rollstd, label='Rolling std(3)',color='black')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
# Out:
# Text(0.5, 1.0, 'Rolling Mean & Standard Deviation')

# %% [markdown]
# __Insights:__
#
# - In the dataset, we could see __variation/std dev across the years__.
# - In this dataset, __mean__ value is __slightly higher__ then the __median__ value. It means, data is somewhat skewed.

# %% [markdown]
# ### Plot a year on year boxplot

# %%
#Yearwise Rose wine Sales Box plot
fig, ax = plt.subplots(figsize=(16,4))
sns.boxplot(x = df.index.year, y = df.Rose,data= df, ax=ax,whis=1.5)
plt.title('Rose Wine: Yearwise Box Plot')
plt.xlabel('Years');
plt.ylabel('Yearly Wine Sales: Rose');
plt.grid();

# %% [markdown]
# __Insights:__
#
# In yearwise boxplot, one key inference which is coming out as __median sales value of across the year having decersing trend__. Further, __Year 1980 and 1981 are the highest sales years__ amongst other years.

# %% [markdown]
# ### Plot a monthly boxplot by taking all the years into account

# %%
#Monthwise Rose wine Sales Box plot
fig, ax = plt.subplots(figsize=(16,4))
sns.boxplot(x = df.index.month_name(), y = df.Rose,data= df, ax=ax,whis=1.5)
plt.title('Rose Wine: Monthwise Box Plot')
plt.xlabel('Month');
plt.ylabel('Monthwise Wine Sales: Rose');
plt.grid();

# %% [markdown]
# ### Plot a monthplot of the given time series

# %%
from statsmodels.graphics.tsaplots import month_plot

#Monthplot Rose wine Sales
fig, ax = plt.subplots(figsize=(16,4))
month_plot(df, ax=ax)
plt.title('Rose Wine: Month Plot')
plt.xlabel('Month');
plt.ylabel('Monthplot Wine Sales: Rose');
plt.grid();

# %% [markdown]
# ### Plot the Time Series according to different months for different years

# %%
yearly_across_months = pd.pivot_table(df, values = 'Rose', columns = df.index.month, 
                                        index = df.index.year)

yearly_across_months
# Out:
# YearMonth     1      2      3     4      5      6          7          8   \
# YearMonth
# 1980       112.0  118.0  129.0  99.0  116.0  168.0  118.00000  129.00000
# 1981       126.0  129.0  124.0  97.0  102.0  127.0  222.00000  214.00000
# 1982        89.0   77.0   82.0  97.0  127.0  121.0  117.00000  117.00000
# 1983        75.0  108.0  115.0  85.0  101.0  108.0  109.00000  124.00000
# 1984        88.0   85.0  112.0  87.0   91.0   87.0   87.00000  142.00000
# 1985        61.0   82.0  124.0  93.0  108.0   75.0   87.00000  103.00000
# 1986        57.0   65.0   67.0  71.0   76.0   67.0  110.00000  118.00000
# 1987        58.0   65.0   70.0  86.0   93.0   74.0   87.00000   73.00000
# 1988        63.0  115.0   70.0  66.0   67.0   83.0   79.00000   77.00000
# 1989        71.0   60.0   89.0  74.0   73.0   91.0   86.00000   74.00000
# 1990        43.0   69.0   73.0  77.0   69.0   76.0   78.00000   70.00000
# 1991        54.0   55.0   66.0  65.0   60.0   65.0   96.00000   55.00000
# 1992        34.0   47.0   56.0  53.0   53.0   55.0   67.00000   52.00000
# 1993        33.0   40.0   46.0  45.0   41.0   55.0   57.00000   54.00000
# 1994        30.0   35.0   42.0  48.0   44.0   45.0   45.34978   44.51237
# 1995        30.0   39.0   45.0  52.0   28.0   40.0   62.00000        NaN
#
# YearMonth     9      10     11     12
# YearMonth
# 1980       205.0  147.0  150.0  267.0
# 1981       118.0  141.0  154.0  226.0
# 1982       106.0  112.0  134.0  169.0
# 1983       105.0   95.0  135.0  164.0
# 1984        95.0  108.0  139.0  159.0
# 1985        90.0  108.0  123.0  129.0
# 1986        99.0   85.0  107.0  141.0
# 1987       101.0  100.0   96.0  157.0
# 1988       102.0  116.0  100.0  135.0
# 1989        87.0   87.0  109.0  137.0
# 1990        83.0   65.0  110.0  132.0
# 1991        71.0   63.0   74.0  106.0
# 1992        46.0   51.0   58.0   91.0
# 1993        46.0   52.0   48.0   77.0
# 1994        46.0   51.0   63.0   84.0
# 1995         NaN    NaN    NaN    NaN

# %%
fig, ax = plt.subplots(figsize=(16,4))
yearly_across_months.plot(ax=ax)
plt.title('Rose Wine: Yearwise across months')
plt.xlabel('Year');
plt.ylabel('Monthwise Wine Sales: Rose');
plt.grid();

# %% [markdown]
# __Insights:__
#
# __Rose:__ In monthwise boxplot, one key inference which is coming out is __across the year, median sales is decreasing but if we see the monthwise plot it looks like as month progresses sales is increasing and highest sales across the month is coming from "December"__.
#
# Further, __month plot stats that there is variations in means sales with the months as well "Jul to Sept and Dec"__ have this type of trend.

# %% [markdown]
# ### Lag plot

# %%
from pandas.plotting import lag_plot
lag_plot(df)
plt.show();

# %% [markdown]
# __Insights:__
#
# - If the points cluster along a diagonal line from the bottom-left to the top-right of the plot, it suggests a positive correlation relationship.
# - If the points cluster along a diagonal line from the top-left to the bottom-right, it suggests a negative correlation relationship.
# - Either relationship is good as they can be modeled.
#
# More points tighter in to the diagonal line suggests a stronger relationship and more spread from the line suggests a weaker relationship. A ball in the middle or a spread across the plot suggests a weak or no relationship.
#
# In this dataset, we could see __weak relationship__ between the months is coming out because of spreaded points.

# %% [markdown]
# ## Decompose the Time Series

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 15,8

# %%
import  statsmodels.api          as       sm
from statsmodels.tsa.seasonal import seasonal_decompose

# %% [markdown]
# ### Additive Decomposition

# %%
## Additive Decomposition: Rose
decomposition_a = sm.tsa.seasonal_decompose(df,model='additive')
decomposition_a.plot();

# %% [markdown]
# __Insights:__
#
# In this additive decomposition, we could see that:
#
# - Trend value is moving from 150 to 50. so eventually promising decerasing trend coming out.
# - Seasonality, out of mean of 100, around 50 is the seasonality which means, this dataset has the seasonality.
# - Residuals, the range of the residual is also around +/- 50 (which leads to noise).

# %%
## Getting the individual components from the Additive Decomposition: Rose
trend_a = decomposition_a.trend
seasonality_a = decomposition_a.seasonal
residual_a = decomposition_a.resid

print('Trend: Rose','\n',trend_a.head(12),'\n')
print('Seasonality: Rose','\n',seasonality_a.head(12),'\n')
print('Residual: Rose','\n',residual_a.head(12),'\n')
# Out:
# Trend: Rose
#  YearMonth
# 1980-01-01           NaN
# 1980-02-01           NaN
# 1980-03-01           NaN
# 1980-04-01           NaN
# 1980-05-01           NaN
# 1980-06-01           NaN
# 1980-07-01    147.083333
# 1980-08-01    148.125000
# 1980-09-01    148.375000
# 1980-10-01    148.083333
# 1980-11-01    147.416667
# 1980-12-01    145.125000
# Name: trend, dtype: float64
#
# Seasonality: Rose
#  YearMonth
# 1980-01-01   -27.902228
# 1980-02-01   -17.432196
# 1980-03-01    -9.278959
# 1980-04-01   -15.091459
# 1980-05-01   -10.189673
# 1980-06-01    -7.671816
# 1980-07-01     4.904424
# 1980-08-01     5.429152
# 1980-09-01     2.781105
# 1980-10-01     1.878328
# 1980-11-01    16.853328
# 1980-12-01    55.719994
# Name: seasonal, dtype: float64
#
# Residual: Rose
#  YearMonth
# 1980-01-01          NaN
# 1980-02-01          NaN
# 1980-03-01          NaN
# 1980-04-01          NaN
# 1980-05-01          NaN
# 1980-06-01          NaN
# 1980-07-01   -33.987757
# 1980-08-01   -24.554152
# 1980-09-01    53.843895
# 1980-10-01    -2.961661
# 1980-11-01   -14.269994
# 1980-12-01    66.155006
# Name: resid, dtype: float64

# %%
#Plot with original dataset with only trend component: Rose
df.plot(figsize=(16,4))
trend_a.plot()
plt.legend(["Original Time Series for Rose", "Only Trend Component for Rose"]);

# %% [markdown]
# ### Multiplicative Decomposition

# %%
## Multiplicative Decomposition: Rose
decomposition_m = sm.tsa.seasonal_decompose(df,model='multiplicative')
decomposition_m.plot();

# %% [markdown]
# __Insights:__
#
# In this additive decomposition, we could see that:
#
# - Trend value is moving from 150 to 50. so eventually promising trend coming out.
# - Seasonality, is almost 50%.
# - Residuals, are almost +/- 50%. (which leads to noise).

# %%
## Getting the individual components from the Multiplicative Decomposition: Rose
trend_m = decomposition_m.trend
seasonality_m = decomposition_m.seasonal
residual_m = decomposition_m.resid

print('Trend: Rose','\n',trend_m.head(12),'\n')
print('Seasonality: Rose','\n',seasonality_m.head(12),'\n')
print('Residual: Rose','\n',residual_m.head(12),'\n')
# Out:
# Trend: Rose
#  YearMonth
# 1980-01-01           NaN
# 1980-02-01           NaN
# 1980-03-01           NaN
# 1980-04-01           NaN
# 1980-05-01           NaN
# 1980-06-01           NaN
# 1980-07-01    147.083333
# 1980-08-01    148.125000
# 1980-09-01    148.375000
# 1980-10-01    148.083333
# 1980-11-01    147.416667
# 1980-12-01    145.125000
# Name: trend, dtype: float64
#
# Seasonality: Rose
#  YearMonth
# 1980-01-01    0.670192
# 1980-02-01    0.806215
# 1980-03-01    0.901294
# 1980-04-01    0.854174
# 1980-05-01    0.889548
# 1980-06-01    0.924116
# 1980-07-01    1.058182
# 1980-08-01    1.034409
# 1980-09-01    1.017769
# 1980-10-01    1.022706
# 1980-11-01    1.192516
# 1980-12-01    1.628878
# Name: seasonal, dtype: float64
#
# Residual: Rose
#  YearMonth
# 1980-01-01         NaN
# 1980-02-01         NaN
# 1980-03-01         NaN
# 1980-04-01         NaN
# 1980-05-01         NaN
# 1980-06-01         NaN
# 1980-07-01    0.758155
# 1980-08-01    0.841916
# 1980-09-01    1.357513
# 1980-10-01    0.970645
# 1980-11-01    0.853258
# 1980-12-01    1.129485
# Name: resid, dtype: float64

# %%
#Plot with original dataset with only trend component: Rose
df.plot(figsize=(16,4))
trend_m.plot()
plt.legend(["Original Time Series for Rose", "Only Trend Component for Rose"]);

# %% [markdown]
# # Train - Test Split

# %%
train    =   df[df.index<'1991']
test     =   df[df.index>='1991']

# %%
print("Train Dataset: Rose")
print(train.head(2))
print(train.tail(2))
print('\n')
print("Train Dataset Shape:", train.shape)
print('\n')
print("Test Dataset: Rose")
print(test.head(2))
print(test.tail(2))
print('\n')
print("Test Dataset Shape:", test.shape)
# Out:
# Train Dataset: Rose
#              Rose
# YearMonth
# 1980-01-01  112.0
# 1980-02-01  118.0
#              Rose
# YearMonth
# 1990-11-01  110.0
# 1990-12-01  132.0
#
#
# Train Dataset Shape: (132, 1)
#
#
# Test Dataset: Rose
#             Rose
# YearMonth
# 1991-01-01  54.0
# 1991-02-01  55.0
#             Rose
# YearMonth
# 1995-06-01  40.0
# 1995-07-01  62.0
#
#
# Test Dataset Shape: (55, 1)

# %%
### Plot data
train['Rose'].plot(figsize=(16,4), title= 'Rose Wine: Train & Test Split', fontsize=14)
test['Rose'].plot(figsize=(16,4), title= 'Rose Wine: Train & Test Split', fontsize=14)
# Out:
# <AxesSubplot:title={'center':'Rose Wine: Train & Test Split'}, xlabel='YearMonth'>

# %% [markdown]
# # Model Building using various Time series techniques

# %% [markdown]
# ## Model 1: Regression on Time

# %%
#Creating copy of train and test for this model
train_reg   = train.copy()
test_reg    = test.copy()

# %%
# creating time variable for train data which would be useful for this model
time       = [i+1 for i in range(len(train_reg))]
train_reg['time'] = time
train_reg.head(2)
# Out:
#              Rose  time
# YearMonth
# 1980-01-01  112.0     1
# 1980-02-01  118.0     2

# %%
# creating time variable for test data which would be useful for this model
time       = [i+1 for i in range(len(test_reg))]
test_reg['time'] = time
test_reg.head(2)
# Out:
#             Rose  time
# YearMonth
# 1991-01-01  54.0     1
# 1991-02-01  55.0     2

# %%
#Train test split based on times eries variable
x_train_reg = train_reg.drop('Rose', axis=1)
x_test_reg  = test_reg.drop('Rose', axis=1)
y_train_reg = train_reg[['Rose']]
y_test_reg  = test_reg[['Rose']]

# %%
# fit the linear regression model
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train_reg, y_train_reg)
# Out:
# LinearRegression()

# %%
#predictions on test data
predictions         = model.predict(x_test_reg)
y_test_reg['RegOnTime'] = predictions

#graphical view on train, test data including regression on time (line)
plt.figure(figsize=(16,4))
plt.plot(train_reg['Rose'], label='Train_Reg: Rose')
plt.plot(test_reg['Rose'], label='Test_Reg: Rose')
plt.plot(y_test_reg['RegOnTime'], label='Regression On Time: Rose')
plt.legend(loc='best')

# %%
rmse_reg = sqrt(mean_squared_error(test_reg.Rose, y_test_reg.RegOnTime))
rmse_reg = round(rmse_reg, 3)
print("For RegressionOnTime: Rose,  RMSE is %3.3f" %(rmse_reg))
# Out:
# For RegressionOnTime: Rose,  RMSE is 71.617

# %%
#store the RMSE details in the table
resultsDf= pd.DataFrame({'Model':['RegressionOnTime'], 'WineType':['Rose'], 'Test_RMSE': [rmse_reg]})

# %% [markdown]
# ## Model 2: Regression on Time With Seasonal Components

# %%
#Creating copy of train and test for this model
train_ROTS   = train.copy()
test_ROTS    = test.copy()

# %%
# define time and monthseasonality for train data
time = [i+1 for i in range(len(train_ROTS))]
train_ROTS['time'] = time
monthSeasonality = ['m1', 'm2', 'm3', 'm4', 'm5', 'm6', 'm7', 'm8', 'm9', 'm10', 'm11', 'm12'] #defining the 12 months

# define time and monthseasonality for test data
# excluding year which doesn't have full year seasonality incldued 
#(i.e. 1995 have only 7 months hence exluding the same from test dataset)
time = [i+1 for i in range(len(test_ROTS)-7)]
test_ROTS = test_ROTS[test_ROTS.index <= '1994-12-01']
test_ROTS['time'] = time
monthSeasonality = ['m1', 'm2', 'm3', 'm4', 'm5', 'm6', 'm7', 'm8', 'm9', 'm10', 'm11', 'm12'] #defining the 12 months

# %%
train_ROTS['monthSeasonality'] = monthSeasonality * 11  # it is multiplied by 11 as there are 132 observations
train_ROTS.head(2)
# Out:
#              Rose  time monthSeasonality
# YearMonth
# 1980-01-01  112.0     1               m1
# 1980-02-01  118.0     2               m2

# %%
test_ROTS['monthSeasonality'] = monthSeasonality * 4  # it is multiplied by 4 as there are 48 observations
test_ROTS.head(2)
# Out:
#             Rose  time monthSeasonality
# YearMonth
# 1991-01-01  54.0     1               m1
# 1991-02-01  55.0     2               m2

# %%
train_ROTSComplete = pd.get_dummies(train_ROTS, drop_first=True)
train_ROTSComplete.head(2).T
# Out:
# YearMonth             1980-01-01  1980-02-01
# Rose                       112.0       118.0
# time                         1.0         2.0
# monthSeasonality_m10         0.0         0.0
# monthSeasonality_m11         0.0         0.0
# monthSeasonality_m12         0.0         0.0
# monthSeasonality_m2          0.0         1.0
# monthSeasonality_m3          0.0         0.0
# monthSeasonality_m4          0.0         0.0
# monthSeasonality_m5          0.0         0.0
# monthSeasonality_m6          0.0         0.0
# monthSeasonality_m7          0.0         0.0
# monthSeasonality_m8          0.0         0.0
# monthSeasonality_m9          0.0         0.0

# %%
test_ROTSComplete = pd.get_dummies(test_ROTS, drop_first=True)
test_ROTSComplete.head(2).T
# Out:
# YearMonth             1991-01-01  1991-02-01
# Rose                        54.0        55.0
# time                         1.0         2.0
# monthSeasonality_m10         0.0         0.0
# monthSeasonality_m11         0.0         0.0
# monthSeasonality_m12         0.0         0.0
# monthSeasonality_m2          0.0         1.0
# monthSeasonality_m3          0.0         0.0
# monthSeasonality_m4          0.0         0.0
# monthSeasonality_m5          0.0         0.0
# monthSeasonality_m6          0.0         0.0
# monthSeasonality_m7          0.0         0.0
# monthSeasonality_m8          0.0         0.0
# monthSeasonality_m9          0.0         0.0

# %%
x_train_ROTS  = train_ROTSComplete.drop('Rose', axis=1)
x_test_ROTS   = test_ROTSComplete.drop('Rose', axis=1)
y_train_ROTS  = train_ROTSComplete[['Rose']]
y_test_ROTS   = test_ROTSComplete[['Rose']]

# %%
model    = LinearRegression()
model.fit(x_train_ROTS, y_train_ROTS)
# Out:
# LinearRegression()

# %%
predictions = model.predict(x_test_ROTS)
y_test_ROTS['RegOnTimeSeasonal'] = predictions

plt.figure(figsize=(16,4))
plt.plot(train_ROTSComplete['Rose'], label='Train_RegonTimeSeasonal')
plt.plot(test_ROTSComplete['Rose'], label='Test_RegonTimeSeasonal')
plt.plot(y_test_ROTS['RegOnTimeSeasonal'], label='Regression On Time With Seasonal Components',color='black')
plt.legend(loc='best')

# %%
rmse_ROTS = sqrt(mean_squared_error(test_ROTSComplete.Rose, y_test_ROTS.RegOnTimeSeasonal))
rmse_ROTS = round(rmse_ROTS,3)
print("For RegOnTimeSeasonal,  RMSE is %3.3f" %(rmse_ROTS))
# Out:
# For RegOnTimeSeasonal,  RMSE is 73.425

# %%
#store the RMSE details in the table
tempResultsDf= pd.DataFrame({'Model':['RegressionOnTimeSeasonal'], 'WineType':['Rose'],
                              'Test_RMSE': [rmse_ROTS]})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# ## Model 3: Naive Approach:  𝑦̂ 𝑡+1=𝑦𝑡

# %%
dd_s = np.asarray(train.Rose)
y_hat_s = test.copy()
y_hat_s['naive'] = dd_s[len(dd_s)-1]

# %%
plt.figure(figsize=(16,4))
plt.plot(train.index, train['Rose'], label='Train_Naive')
plt.plot(test.index,test['Rose'], label='Test_Naive')
plt.plot(y_hat_s.index,y_hat_s['naive'], label='Naive Forecast')
plt.legend(loc='best')
plt.title("Naive Forecast: Rose")
# Out:
# Text(0.5, 1.0, 'Naive Forecast: Rose')

# %%
rmse_Naive = sqrt(mean_squared_error(test.Rose, y_hat_s.naive))
rmse_Naive = round(rmse_Naive, 3)
print("For Naive model,  RMSE is %3.3f" %(rmse_Naive))
# Out:
# For Naive model,  RMSE is 79.741

# %%
#store the RMSE details in the table
tempResultsDf= pd.DataFrame({'Model':['Naive model'], 'WineType':['Rose'],
                              'Test_RMSE': [rmse_Naive]})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# We can infer from the RMSE values. Furrther above table shows that:
#
# - __Naive method and Regression on Time Seasonal models are not suited__.
#
# - __Regression on Time model__ is the __best suit__. But we can still _improve our score by adopting different techniques_.
#
# Now we will look at __another techniques and try to improve our score__.

# %% [markdown]
# ## Model 4: Simple Average

# %%
y_hat_avg_s = test.copy()

y_hat_avg_s['avg_forecast'] = train['Rose'].mean()

plt.figure(figsize=(16,4))
plt.plot(train['Rose'], label='trainimpleAvg')
plt.plot(test['Rose'], label='testimpleAvg')
plt.plot(y_hat_avg_s['avg_forecast'], label='Average Forecast')
plt.legend(loc='best')

# %%
rmse_SA = sqrt(mean_squared_error(test.Rose, y_hat_avg_s.avg_forecast))
rmse_SA = round(rmse_SA, 3)
print("For Simple Average model,  RMSE is %3.3f" %(rmse_SA))
# Out:
# For Simple Average model,  RMSE is 53.484

# %%
#store the RMSE details in the table
tempResultsDf= pd.DataFrame({'Model':['Simple Average'], 'WineType':['Rose'],
                              'Test_RMSE': [rmse_SA]})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# ## Model 5: Moving Average(MA)

# %%
df_MA = df.copy()

# %%
# rolling MA details
df_MA['moving_avg_forecast_3']  = df_MA['Rose'].rolling(3).mean()
df_MA['moving_avg_forecast_4']  = df_MA['Rose'].rolling(4).mean()
df_MA['moving_avg_forecast_5']  = df_MA['Rose'].rolling(5).mean()
df_MA['moving_avg_forecast_6']  = df_MA['Rose'].rolling(6).mean()
df_MA['moving_avg_forecast_8']  = df_MA['Rose'].rolling(8).mean()
df_MA['moving_avg_forecast_12'] = df_MA['Rose'].rolling(12).mean()

# %%
cols = ['moving_avg_forecast_3','moving_avg_forecast_4', 
        'moving_avg_forecast_5','moving_avg_forecast_6','moving_avg_forecast_8','moving_avg_forecast_12']

# %%
#Creating train and test set 
train_MA = df_MA[df_MA.index<'1991'] 
test_MA  = df_MA[df_MA.index>='1991']

# %%
y_hat_avg_MA = test_MA.copy()

for col_name in cols:
    
    plt.figure(figsize=(16,4))
    plt.plot(train_MA['Rose'], label='Train_MA')
    plt.plot(test_MA['Rose'], label='Test_MA')
    plt.plot(y_hat_avg_MA[col_name], label = col_name, color = 'black')
    plt.legend(loc = 'best')
    
    rmse_MA = sqrt(mean_squared_error(test_MA.Rose, y_hat_avg_MA[col_name]))
    rmse_MA = round(rmse_MA, 3)
    print("For Moving Average model, %s  RMSE is %3.3f" %(col_name, rmse_MA))
    
    #Defining the data frame with the model evaluation parameters
    tempResultsDf= pd.DataFrame({'Model':[col_name], 'WineType':['Rose'], 'Test_RMSE': [rmse_MA]})
    resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')
# Out:
# For Moving Average model, moving_avg_forecast_3  RMSE is 14.129
# For Moving Average model, moving_avg_forecast_4  RMSE is 14.457
# For Moving Average model, moving_avg_forecast_5  RMSE is 14.481
# For Moving Average model, moving_avg_forecast_6  RMSE is 14.572
# For Moving Average model, moving_avg_forecast_8  RMSE is 14.803
# For Moving Average model, moving_avg_forecast_12  RMSE is 15.239

# %% [markdown]
# ## Model 6: Simple Exponential Smoothing (SES)

# %%
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt

# %%
# create class
model_SES = SimpleExpSmoothing(train['Rose'])

# %%
model_SES_fit = model_SES.fit(optimized = True)

# %%
print('')
print('== Simple Exponential Smoothing (SES) ')
print('')

print('')
print('Smoothing Level', np.round(model_SES_fit.params['smoothing_level'], 4))
print('Initial Level',   np.round(model_SES_fit.params['initial_level'], 4))
print('')
# Out:
# == Simple Exponential Smoothing (SES)
#
#
# Smoothing Level 0.0987
# Initial Level 134.387

# %%
y_hat_avg_SES = test.copy()
y_hat_avg_SES['SES']     = model_SES_fit.forecast(len(test['Rose']))

alpha_value          = np.round(model_SES_fit.params['smoothing_level'], 4)


plt.figure(figsize=(12,4))
plt.plot(train.index, train['Rose'], label = 'Train_SES')
plt.plot(test.index, test['Rose'],   label = 'Test_SES')
plt.plot(test.index, y_hat_avg_SES.SES,   label = 'SES_OPT')
plt.title('SES with alpha ' + str(alpha_value))
plt.legend(loc='best') 
plt.show()

# %%
rmse_SES = sqrt(mean_squared_error(test['Rose'], y_hat_avg_SES.SES))
rmse_SES = round(rmse_SES, 3)
print("For SES model: For alpha = %1.2f,  RMSE is %3.3f" %(alpha_value,rmse_SES))
# Out:
# For SES model: For alpha = 0.10,  RMSE is 36.820

# %% [markdown]
# ## Model 7: SES model - Best alpha with least RMSE

# %%
resultsDf_model = pd.DataFrame({'Alpha Values':[],'Test RMSE': []})
resultsDf_model

y_hat_leastRMSE_SES = test.copy()

for i in np.arange(0.01,1,0.01):
    model_SES_alpha_i = model_SES.fit(smoothing_level=i,optimized=False,use_brute=True)
    y_hat_leastRMSE_SES['predict',i] = model_SES_alpha_i.forecast(steps=len(test))
    
    rmse_model7_test_i = metrics.mean_squared_error(test['Rose'],y_hat_leastRMSE_SES['predict',i],squared=False)
        
    resultsDf_model = resultsDf_model.append({'Alpha Values':i
                                              ,'Test RMSE':rmse_model7_test_i}, ignore_index=True)

# %%
SES_least_rmse = resultsDf_model.sort_values(by=['Test RMSE'],ascending=True)
SES_least_rmse.head(2)
# Out:
#    Alpha Values  Test RMSE
# 6          0.07  36.459396
# 7          0.08  36.486588

# %%
print("For SES model(least RMSE): For alpha = %3.2f,  RMSE is %3.3f"
    %(SES_least_rmse.iloc[0].values[0],SES_least_rmse.iloc[0].values[1]))
# Out:
# For SES model(least RMSE): For alpha = 0.07,  RMSE is 36.459

# %%
plt.figure(figsize=(16,4))
plt.plot(train.index, train['Rose'], label = 'Train_SES')
plt.plot(test.index, test['Rose'],   label = 'Test_SES')
#at this location we have alpha value with predict0.07
plt.plot(test.index, y_hat_leastRMSE_SES.iloc[:,1],   label = 'SES_LEAST_RMSE') 
plt.title('SES LEAST RMSE with alpha 0.07')
plt.legend(loc='best') 
plt.show()

# %%
tempResultsDf= pd.DataFrame({'Model': 'SES(least RMSE)(L:0.07)', 'WineType':['Rose'],
                              'Test_RMSE': [SES_least_rmse.iloc[0].values[1]]})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# ## Model 8: Holt's Linear Trend Method (Double Exponential Smoothing)

# %%
import statsmodels.api as sm

# %%
y_hat_avg_DES = test.copy()

model_DES = Holt(train['Rose'])

model_DES_fit = Holt(train['Rose']).fit(optimized=True)

y_hat_avg_DES['Holt_linear'] = model_DES_fit.forecast(len(test))

# %%
print('')
print('==Holt model Exponential Smoothing Parameters ==')
print('')
alpha_DES_value = np.round(model_DES_fit.params['smoothing_level'], 4)
beta_DES_value  = np.round(model_DES_fit.params['smoothing_trend'], 4)

print('Smoothing Level', alpha_DES_value)
print('Smoothing Trend', beta_DES_value)
print('Initial Level',   np.round(model_DES_fit.params['initial_level'], 4))
print('')
# Out:
# ==Holt model Exponential Smoothing Parameters ==
#
# Smoothing Level 0.0
# Smoothing Trend 0.0
# Initial Level 137.8155

# %%
plt.figure(figsize=(16,4))
plt.plot(train['Rose'], label='Train_DES')
plt.plot(test['Rose'], label='Test_DES')
plt.plot(y_hat_avg_DES['Holt_linear'], label='Holt_linear')
plt.title('DES with alpha ' + str(alpha_DES_value) + ' and beta ' + str(beta_DES_value))
plt.legend(loc='best')
plt.show()

# %%
rmse_DES            =  np.sqrt(mean_squared_error(test['Rose'], y_hat_avg_DES['Holt_linear']))

print("For alpha = %1.2f, For beta = %1.2f,  RMSE is %4.2f" 
      %(alpha_DES_value, beta_DES_value, rmse_DES))
# Out:
# For alpha = 0.00, For beta = 0.00,  RMSE is 15.28

# %%
tempResultsDf= pd.DataFrame({'Model': 'DES(Holt_linear)(L:0.0,T:0.0)', 'WineType':['Rose'],
                              'Test_RMSE': rmse_DES})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# ## Model 9: DES model - Best alpha and beta with least RMSE

# %%
## First we will define an empty dataframe to store our values from the loop

resultsDfDES_model = pd.DataFrame({'Alpha Values':[],'Beta Values':[],'Test RMSE': []})
resultsDfDES_model

y_hat_leastRMSE_DES = test.copy()

modelDES = Holt(train['Rose'])

for i in np.arange(0.01,1,0.01):
    for j in np.arange(0.01,1,0.01):
        modelDES_alpha_i_j = modelDES.fit(smoothing_level=i,smoothing_trend=j,optimized=False)
        y_hat_leastRMSE_DES['predict',i,j] = modelDES_alpha_i_j.forecast(steps=len(test))
                
        rmse_model9DES_test = metrics.mean_squared_error(test['Rose'],y_hat_leastRMSE_DES['predict',i,j],squared=False)
        
        resultsDfDES_model = resultsDfDES_model.append({'Alpha Values':i,'Beta Values':j
                                          ,'Test RMSE':rmse_model9DES_test}, ignore_index=True)

# %%
DES_least_rmse = resultsDfDES_model.sort_values(by=['Test RMSE'],ascending=True)
DES_least_rmse.head(2)
# Out:
#      Alpha Values  Beta Values  Test RMSE
# 343          0.04         0.47  14.566308
# 222          0.03         0.25  14.687964

# %%
plt.figure(figsize=(12,4))
plt.plot(train.index, train['Rose'], label = 'Train_DES')
plt.plot(test.index, test['Rose'],   label = 'Test_DES')

plt.plot(test.index, y_hat_leastRMSE_DES['predict',0.04,0.46],   label = 'DES_LEAST_RMSE') 
plt.title('DES LEAST RMSE with alpha 0.04 and beta 0.47')
plt.legend(loc='best') 
plt.show()

# %%
print("For DES model(least RMSE): For alpha = %1.2f, beta = %1.2f, RMSE is %3.2f"
    %(DES_least_rmse.iloc[0].values[0],DES_least_rmse.iloc[0].values[1],DES_least_rmse.iloc[0].values[2]))
# Out:
# For DES model(least RMSE): For alpha = 0.04, beta = 0.47, RMSE is 14.57

# %%
tempResultsDf= pd.DataFrame({'Model': 'DES(least RMSE)(L:0.04,T:0.47)', 'WineType':['Rose'],
                              'Test_RMSE': [DES_least_rmse.iloc[0].values[2]]})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# ## Method 10: Holt-Winters Method - Additive seasonality

# %%
y_hat_TES_a_avg = test.copy()

# %%
model_TES_a_fit = ExponentialSmoothing(np.asarray(train['Rose']),
                                         seasonal_periods = 12 ,trend='add', seasonal='add').fit()

# %%
y_hat_TES_a_avg['Holt_Winter'] = model_TES_a_fit.forecast(len(test))

# %%
print('')
print('== Holt-Winters Additive ETS(A,A,A) Parameters ==')
print('')
alpha_TES_a_value = np.round(model_TES_a_fit.params['smoothing_level'], 4)
beta_TES_a_value  = np.round(model_TES_a_fit.params['smoothing_trend'], 4)
gamma_TES_a_value = np.round(model_TES_a_fit.params['smoothing_seasonal'], 4) 

print('Smoothing Level: ', alpha_TES_a_value)
print('Smoothing Trend: ', beta_TES_a_value)
print('Smoothing Seasonal: ', gamma_TES_a_value)
print('Initial Level: ', np.round(model_TES_a_fit.params['initial_level'], 4))
print('Initial Trend: ', np.round(model_TES_a_fit.params['initial_trend'], 4))
print('Initial Seasons: ', np.round(model_TES_a_fit.params['initial_seasons'], 4))
print('')
# Out:
# == Holt-Winters Additive ETS(A,A,A) Parameters ==
#
# Smoothing Level:  0.0883
# Smoothing Trend:  0.0
# Smoothing Seasonal:  0.0013
# Initial Level:  77.0094
# Initial Trend:  -0.5495
# Initial Seasons:  [ 38.7425  51.0657  58.9921  48.2684  56.9677  62.3791  72.3964  78.5321
#   74.5857  72.7823  90.8438 133.1995]

# %%
plt.figure(figsize=(12,4))
plt.plot(train['Rose'], label='Train_TES')
plt.plot(test['Rose'], label='Test_TES')
plt.plot(y_hat_TES_a_avg['Holt_Winter'], label='Holt_Winter', color='black')
plt.title('Holt-Winters Additive ETS(A,A,A) Parameters:\n  alpha = ' + 
          str(alpha_TES_a_value) + '  Beta:' + 
          str(beta_TES_a_value) +
          '  Gamma: ' + str(gamma_TES_a_value))
plt.legend(loc='best')

# %%
rmse_TES_a             =  np.sqrt(mean_squared_error(test['Rose'], y_hat_TES_a_avg['Holt_Winter']))

print("For TES(Additive) model: alpha = %1.2f, beta = %1.2f, gamma = %1.2f, RMSE is %3.2f" 
      %(alpha_TES_a_value, beta_TES_a_value, gamma_TES_a_value, rmse_TES_a))
# Out:
# For TES(Additive) model: alpha = 0.09, beta = 0.00, gamma = 0.00, RMSE is 14.30

# %%
#store the RMSE details in the table
tempResultsDf= pd.DataFrame({'Model': 'TES(Holt_Winter)-Add(L:0.09,T:0.0,S:0.0)', 'WineType':['Rose'],
                              'Test_RMSE': rmse_TES_a})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# ## Method 11: Holt-Winters Method - Multiplicative seasonality

# %%
y_hat_TES_m_avg = test.copy()

# %%
model_TES_m_fit = ExponentialSmoothing(np.asarray(train['Rose']),
                                         seasonal_periods = 12 ,trend='add', seasonal='mul').fit()

# %%
y_hat_TES_m_avg['Holt_Winter'] = model_TES_m_fit.forecast(len(test))

# %%
print('')
print('== Holt-Winters Multiplicative ETS(A,A,M) Parameters ==')
print('')
alpha_TES_m_value = np.round(model_TES_m_fit.params['smoothing_level'], 4)
beta_TES_m_value  = np.round(model_TES_m_fit.params['smoothing_trend'], 4)
gamma_TES_m_value = np.round(model_TES_m_fit.params['smoothing_seasonal'], 4) 

print('Smoothing Level: ', alpha_TES_m_value)
print('Smoothing Trend: ', beta_TES_m_value)
print('Smoothing Seasonal: ', gamma_TES_m_value)
print('Initial Level: ', np.round(model_TES_m_fit.params['initial_level'], 4))
print('Initial Trend: ', np.round(model_TES_m_fit.params['initial_trend'], 4))
print('Initial Seasons: ', np.round(model_TES_m_fit.params['initial_seasons'], 4))
print('')
# Out:
# == Holt-Winters Multiplicative ETS(A,A,M) Parameters ==
#
# Smoothing Level:  0.0639
# Smoothing Trend:  0.0543
# Smoothing Seasonal:  0.0
# Initial Level:  52.7062
# Initial Trend:  -0.3295
# Initial Seasons:  [2.1403 2.4289 2.6533 2.3193 2.6074 2.8435 3.1251 3.323  3.1538 3.0851
#  3.596  4.96  ]

# %%
plt.figure(figsize=(12,4))
plt.plot(train['Rose'], label='Train_TES')
plt.plot(test['Rose'], label='Test_TES')
plt.plot(y_hat_TES_m_avg['Holt_Winter'], label='Holt_Winter', color='black')
plt.title('Holt-Winters Multiplicative ETS(A,A,M) Parameters:\n  alpha = ' + 
          str(alpha_TES_m_value) + '  Beta:' + 
          str(beta_TES_m_value) +
          '  Gamma: ' + str(gamma_TES_m_value))
plt.legend(loc='best')

# %%
rmse_TES_m             =  np.sqrt(mean_squared_error(test['Rose'], y_hat_TES_m_avg['Holt_Winter']))

print("For TES(Multiplicative) alpha = %1.2f, beta = %1.2f, gamma = %1.2f, RMSE is %3.2f" 
      %(alpha_TES_m_value, beta_TES_m_value, gamma_TES_m_value, rmse_TES_m))
# Out:
# For TES(Multiplicative) alpha = 0.06, beta = 0.05, gamma = 0.00, RMSE is 21.29

# %%
#store the RMSE details in the table
tempResultsDf= pd.DataFrame({'Model': 'TES(Holt_Winter)-Mul(L:0.06,T:0.05,S:0.0)', 'WineType':['Rose'],
                              'Test_RMSE': rmse_TES_m})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# __Let's Try some advanced models and get RMSE value corresponding to those models.__

# %% [markdown]
# # Check for stationarity on Time Series data (Full data & Train data).

# %% [markdown]
# What are characteristics of stationarity:
#
# - __Mean__ should be __constant__
#
# - __Variance__ should be __constant__
#
# - __Covariance__ for a time period should be __constant__

# %% [markdown]
# __Hypothesis to check Stationarity:__
#
#  __H0__ : Time series is __non-stationary__
#
#  __H1__ : Time series is __stationary__

# %% [markdown]
# __Note:__ If the series is non-stationary, stationarise the time series by taking a difference of the time series. Then we can use this particular differenced series to train the models. __We do not need to worry about stationarity for the Test Data__ because we are not building any models on the test Data, we are only evaluating our models over there.

# %% [markdown]
# __Auto-Correlation Plot:__

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df)
plt.show();

# %% [markdown]
# __Insights:__
#
# We can quantify the strength and type of relationship between observations and their lags. In statistics, this is called correlation, and when calculated against lag values in time series it is called autocorrelation (self-correlation).
#
# A correlation value calculated between two groups of numbers, such as observations and their lag1 values, results in a number between -1 and 1. The sign of this number indicates a negative or positive correlation respectively.
# A value close to zero suggests a weak correlation, whereas a value closer to -1 or 1 indicates a strong correlation.
# Dotted lines are provided that indicate any correlation values above those lines are statistically significant (meaningful).

# %% [markdown]
# ## ADF Test

# %%
from statsmodels.tsa.stattools import adfuller
from matplotlib.pyplot import figure

# %%
dftest = adfuller(df,regression='ct')
print('dftest statistic is %3.3f' %dftest[0])
print('dftest p-value is' ,dftest[1])
print('Number of lags used' ,dftest[2])
# Out:
# dftest statistic is -2.242
# dftest p-value is 0.46643710204731414
# Number of lags used 13

# %%
dftest = adfuller(train,regression='ct')
print('dftest statistic is %3.3f' %dftest[0])
print('dftest p-value is' ,dftest[1])
print('Number of lags used' ,dftest[2])
# Out:
# dftest statistic is -1.686
# dftest p-value is 0.7569093051047049
# Number of lags used 13

# %% [markdown]
# We see that __𝛼 (alpha) values__ of full dataset and train dataset are __more than 0.05__. Hence, the Time Series data for _Rose wine_ is __non-stationary__.

# %% [markdown]
# ## Convert Non-stationary to Stationary

# %% [markdown]
# __Let's take a difference of order 1 and check whether the Time Series is stationary or not.__

# %%
dftest = adfuller(df.diff(1).dropna(),regression='ct')
print('dftest statistic is %3.3f' %dftest[0])
print('dftest p-value is' ,dftest[1])
print('Number of lags used' ,dftest[2])
# Out:
# dftest statistic is -8.161
# dftest p-value is 3.034192412610866e-11
# Number of lags used 12

# %%
(df.diff(1).dropna()).plot(grid=True,figsize=(16, 4));
plt.title('Rose Wine: Full data with difference order = 1')
# Out:
# Text(0.5, 1.0, 'Rose Wine: Full data with difference order = 1')

# %%
dftest = adfuller(train.diff(1).dropna(),regression='ct')
print('dftest statistic is %3.3f' %dftest[0])
print('dftest p-value is' ,dftest[1])
print('Number of lags used' ,dftest[2])
# Out:
# dftest statistic is -6.804
# dftest p-value is 3.8948313567830344e-08
# Number of lags used 12

# %%
(train.diff(1).dropna()).plot(grid=True,figsize=(16, 4));
plt.title('Rose Wine: Train data with difference order = 1')
# Out:
# Text(0.5, 1.0, 'Rose Wine: Train data with difference order = 1')

# %% [markdown]
# __We see that after taking difference of order 1 the series have become stationary at alpha = 0.05.__

# %% [markdown]
# # Model 12 & 13: Automated version of ARIMA & SARIMA model with least AIC (Akaike Information Criteria) value

# %% [markdown]
# ## ARIMA Model

# %%
## The following loop helps us in getting a combination of different parameters of p and q in the range of 0 and 4
## We have kept the value of d as 1 as we need to take a difference of the series to make it stationary.

import itertools
p = q = range(0, 5)
d= range(1,2)
pdq = list(itertools.product(p, d, q))
print('Some parameter combinations for the Model...')
for i in range(1,len(pdq)):
    print('Model: {}'.format(pdq[i]))
# Out:
# Some parameter combinations for the Model...
# Model: (0, 1, 1)
# Model: (0, 1, 2)
# Model: (0, 1, 3)
# Model: (0, 1, 4)
# Model: (1, 1, 0)
# Model: (1, 1, 1)
# Model: (1, 1, 2)
# Model: (1, 1, 3)
# Model: (1, 1, 4)
# Model: (2, 1, 0)
# Model: (2, 1, 1)
# Model: (2, 1, 2)
# Model: (2, 1, 3)
# Model: (2, 1, 4)
# Model: (3, 1, 0)
# Model: (3, 1, 1)
# Model: (3, 1, 2)
# Model: (3, 1, 3)
# Model: (3, 1, 4)
# Model: (4, 1, 0)
# Model: (4, 1, 1)
# Model: (4, 1, 2)
# Model: (4, 1, 3)
# Model: (4, 1, 4)

# %%
# Creating an empty Dataframe with column names only
ARIMA_AIC = pd.DataFrame(columns=['param', 'AIC'])
ARIMA_AIC
# Out:
# Empty DataFrame
# Columns: [param, AIC]
# Index: []

# %%
from statsmodels.tsa.arima.model import ARIMA

for param in pdq:# running a loop within the pdq parameters defined by itertools
    ARIMA_model = ARIMA(train['Rose'].values,order=param).fit()#fitting the ARIMA model
    #using the parameters from the loop
    print('ARIMA{} - AIC:{}'.format(param,ARIMA_model.aic))#printing the parameters and the AIC
    #from the fitted models
    ARIMA_AIC = ARIMA_AIC.append({'param':param, 'AIC': ARIMA_model.aic}, ignore_index=True)
    #appending the AIC values and the model parameters to the previously created data frame
    #for easier understanding and sorting of the AIC values
# Out:
# ARIMA(0, 1, 0) - AIC:1333.1546729124348
# ARIMA(0, 1, 1) - AIC:1282.3098319748315
# ARIMA(0, 1, 2) - AIC:1279.6715288535752
# ARIMA(0, 1, 3) - AIC:1280.5453761734648
# ARIMA(0, 1, 4) - AIC:1281.676698214394
# ARIMA(1, 1, 0) - AIC:1317.3503105381526
# ARIMA(1, 1, 1) - AIC:1280.5742295380064
# ARIMA(1, 1, 2) - AIC:1279.870723423191
# ARIMA(1, 1, 3) - AIC:1281.8707223309975
# ARIMA(1, 1, 4) - AIC:1279.605262689965
# ARIMA(2, 1, 0) - AIC:1298.6110341604972
# ARIMA(2, 1, 1) - AIC:1281.5078621868588
# ARIMA(2, 1, 2) - AIC:1281.8707222264707
# ARIMA(2, 1, 3) - AIC:1274.694994556771
# ARIMA(2, 1, 4) - AIC:1278.769206293137
# ARIMA(3, 1, 0) - AIC:1297.481091727174
# ARIMA(3, 1, 1) - AIC:1282.4192776271934
# ARIMA(3, 1, 2) - AIC:1283.720740597716
# ARIMA(3, 1, 3) - AIC:1278.656528339799
# ARIMA(3, 1, 4) - AIC:1287.7190768788678
# ARIMA(4, 1, 0) - AIC:1296.3266569004504
# ARIMA(4, 1, 1) - AIC:1283.7931715123068
# ARIMA(4, 1, 2) - AIC:1285.7182485626197
# ARIMA(4, 1, 3) - AIC:1278.4514121325244
# ARIMA(4, 1, 4) - AIC:1282.3460437411716

# %%
ARIMA_least_AIC = ARIMA_AIC.sort_values(by='AIC',ascending=True)
ARIMA_least_AIC.head(2)
# Out:
#         param          AIC
# 13  (2, 1, 3)  1274.694995
# 23  (4, 1, 3)  1278.451412

# %%
## ARIMA(2,1,3) has the lowest AIC
model = ARIMA(train, order=(2,1,3),freq="MS")

results_arima = model.fit()

print(results_arima.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   Rose   No. Observations:                  132
# Model:                 ARIMA(2, 1, 3)   Log Likelihood                -631.347
# Date:                Mon, 28 Jun 2021   AIC                           1274.695
# Time:                        15:27:45   BIC                           1291.946
# Sample:                    01-01-1980   HQIC                          1281.705
#                          - 12-01-1990
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.6775      0.084    -20.007      0.000      -1.842      -1.513
# ar.L2         -0.7283      0.084     -8.685      0.000      -0.893      -0.564
# ma.L1          1.0448      0.662      1.579      0.114      -0.252       2.341
# ma.L2         -0.7719      0.135     -5.713      0.000      -1.037      -0.507
# ma.L3         -0.9047      0.600     -1.507      0.132      -2.082       0.272
# sigma2       860.0026    557.970      1.541      0.123    -233.598    1953.603
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                24.40
# Prob(Q):                              0.88   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.40   Skew:                             0.71
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.57
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
#get prediction start and end dates
pred_start_date = test.index[0]
pred_end_date = test.index[-1]

#get the predictions and residuals
predictions = results_arima.predict(start=pred_start_date, end=pred_end_date)
residuals = test['Rose'] - predictions

# %%
ARIMA_RMSE = metrics.mean_squared_error(test['Rose'],predictions,squared=False)

print("AutoARIMA Model(least AIC)(2,1,3):, RMSE is %3.2f" 
      %(ARIMA_RMSE))
# Out:
# AutoARIMA Model(least AIC)(2,1,3):, RMSE is 36.84

# %%
#store the RMSE details in the table
tempResultsDf= pd.DataFrame({'Model': 'AutoARIMA Model(least AIC)(2,1,3)', 'WineType':['Rose'],
                              'Test_RMSE': ARIMA_RMSE})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# ## SARIMA Model

# %%
import itertools
p = q = range(0,4)
P = Q = range(0,3)
d = range(1,2)
D = range(0,2)
pdq = list(itertools.product(p, d, q))
model_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(P, D, Q))]

# %%
SARIMA_AIC = pd.DataFrame(columns=['param','seasonal', 'AIC'])
SARIMA_AIC
# Out:
# Empty DataFrame
# Columns: [param, seasonal, AIC]
# Index: []

# %%
import statsmodels.api as sm

for param in pdq:
    for param_seasonal in model_pdq:
        SARIMA_model = sm.tsa.statespace.SARIMAX(train,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
            
        results_SARIMA = SARIMA_model.fit()
        print('SARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results_SARIMA.aic))
        SARIMA_AIC = SARIMA_AIC.append({'param':param,'seasonal':param_seasonal ,'AIC': results_SARIMA.aic}, ignore_index=True)
# Out:
# SARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:1323.9657875279158
# SARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:1145.4230827207375
# SARIMA(0, 1, 0)x(0, 0, 2, 12)12 - AIC:976.4375296380888
# SARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:1171.2013438279514
# SARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:965.5057301638521
# SARIMA(0, 1, 0)x(0, 1, 2, 12)12 - AIC:845.8687014776108
# SARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:1139.921738995602
# SARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:1116.0207869386272
# SARIMA(0, 1, 0)x(1, 0, 2, 12)12 - AIC:969.6913635752439
# SARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:982.3269589658807
# SARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:975.3375383601608
# SARIMA(0, 1, 0)x(1, 1, 2, 12)12 - AIC:847.7332182654663
# SARIMA(0, 1, 0)x(2, 0, 0, 12)12 - AIC:960.8812220353041
# SARIMA(0, 1, 0)x(2, 0, 1, 12)12 - AIC:962.8794540697505
# SARIMA(0, 1, 0)x(2, 0, 2, 12)12 - AIC:955.573540894571
# SARIMA(0, 1, 0)x(2, 1, 0, 12)12 - AIC:858.513269837442
# SARIMA(0, 1, 0)x(2, 1, 1, 12)12 - AIC:853.3390729147014
# SARIMA(0, 1, 0)x(2, 1, 2, 12)12 - AIC:842.6282244227037
# SARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:1263.5369097383968
# SARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:1098.5554825918332
# SARIMA(0, 1, 1)x(0, 0, 2, 12)12 - AIC:923.6314049383823
# SARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:1113.766313356193
# SARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:915.0730606717773
# SARIMA(0, 1, 1)x(0, 1, 2, 12)12 - AIC:790.9032809266806
# SARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:1095.793632491807
# SARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:1054.7434330946548
# SARIMA(0, 1, 1)x(1, 0, 2, 12)12 - AIC:918.8573483307921
# SARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:944.2456655529768
# SARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:929.336248852009
# SARIMA(0, 1, 1)x(1, 1, 2, 12)12 - AIC:792.7161670270938
# SARIMA(0, 1, 1)x(2, 0, 0, 12)12 - AIC:914.5982866535927
# SARIMA(0, 1, 1)x(2, 0, 1, 12)12 - AIC:915.3332430461658
# SARIMA(0, 1, 1)x(2, 0, 2, 12)12 - AIC:901.2026795822355
# SARIMA(0, 1, 1)x(2, 1, 0, 12)12 - AIC:810.3194350158664
# SARIMA(0, 1, 1)x(2, 1, 1, 12)12 - AIC:804.1555752468961
# SARIMA(0, 1, 1)x(2, 1, 2, 12)12 - AIC:782.1538715237003
# SARIMA(0, 1, 2)x(0, 0, 0, 12)12 - AIC:1251.667543054104
# SARIMA(0, 1, 2)x(0, 0, 1, 12)12 - AIC:1083.4866975264904
# SARIMA(0, 1, 2)x(0, 0, 2, 12)12 - AIC:913.49384866177
# SARIMA(0, 1, 2)x(0, 1, 0, 12)12 - AIC:1098.6598024297389
# SARIMA(0, 1, 2)x(0, 1, 1, 12)12 - AIC:904.50034884733
# SARIMA(0, 1, 2)x(0, 1, 2, 12)12 - AIC:784.0140955703713
# SARIMA(0, 1, 2)x(1, 0, 0, 12)12 - AIC:1088.8332843413755
# SARIMA(0, 1, 2)x(1, 0, 1, 12)12 - AIC:1045.5400933480246
# SARIMA(0, 1, 2)x(1, 0, 2, 12)12 - AIC:904.8310913611012
# SARIMA(0, 1, 2)x(1, 1, 0, 12)12 - AIC:941.5256923362815
# SARIMA(0, 1, 2)x(1, 1, 1, 12)12 - AIC:915.273113409045
# SARIMA(0, 1, 2)x(1, 1, 2, 12)12 - AIC:785.8237144294175
# SARIMA(0, 1, 2)x(2, 0, 0, 12)12 - AIC:913.0105912257987
# SARIMA(0, 1, 2)x(2, 0, 1, 12)12 - AIC:914.1707545049868
# SARIMA(0, 1, 2)x(2, 0, 2, 12)12 - AIC:887.9375085679542
# SARIMA(0, 1, 2)x(2, 1, 0, 12)12 - AIC:811.5489438178317
# SARIMA(0, 1, 2)x(2, 1, 1, 12)12 - AIC:805.1158488730455
# SARIMA(0, 1, 2)x(2, 1, 2, 12)12 - AIC:774.9691212114999
# SARIMA(0, 1, 3)x(0, 0, 0, 12)12 - AIC:1243.9501216739088
# SARIMA(0, 1, 3)x(0, 0, 1, 12)12 - AIC:1076.7632646084478
# SARIMA(0, 1, 3)x(0, 0, 2, 12)12 - AIC:905.6926533380534
# SARIMA(0, 1, 3)x(0, 1, 0, 12)12 - AIC:1088.3764710136581
# SARIMA(0, 1, 3)x(0, 1, 1, 12)12 - AIC:897.1317873892924
# SARIMA(0, 1, 3)x(0, 1, 2, 12)12 - AIC:778.4427567854126
# SARIMA(0, 1, 3)x(1, 0, 0, 12)12 - AIC:1089.2051361212302
# SARIMA(0, 1, 3)x(1, 0, 1, 12)12 - AIC:1034.841121293578
# SARIMA(0, 1, 3)x(1, 0, 2, 12)12 - AIC:896.836252334144
# SARIMA(0, 1, 3)x(1, 1, 0, 12)12 - AIC:943.5043088714345
# SARIMA(0, 1, 3)x(1, 1, 1, 12)12 - AIC:904.9319970114719
# SARIMA(0, 1, 3)x(1, 1, 2, 12)12 - AIC:780.2386079741269
# SARIMA(0, 1, 3)x(2, 0, 0, 12)12 - AIC:914.9477108987159
# SARIMA(0, 1, 3)x(2, 0, 1, 12)12 - AIC:916.0630996882958
# SARIMA(0, 1, 3)x(2, 0, 2, 12)12 - AIC:880.5509788251987
# SARIMA(0, 1, 3)x(2, 1, 0, 12)12 - AIC:813.4051893208936
# SARIMA(0, 1, 3)x(2, 1, 1, 12)12 - AIC:806.4667724984471
# SARIMA(0, 1, 3)x(2, 1, 2, 12)12 - AIC:767.2243746035127
# SARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:1308.161871082466
# SARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:1135.2955447585698
# SARIMA(1, 1, 0)x(0, 0, 2, 12)12 - AIC:963.9405391257692
# SARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:1164.510301384205
# SARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:953.8813887546752
# SARIMA(1, 1, 0)x(0, 1, 2, 12)12 - AIC:828.8398832821272
# SARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:1124.886078680457
# SARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:1105.4080055023899
# SARIMA(1, 1, 0)x(1, 0, 2, 12)12 - AIC:958.5001972948602
# SARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:962.96985357368
# SARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:964.8516934823646
# SARIMA(1, 1, 0)x(1, 1, 2, 12)12 - AIC:830.3075804966883
# SARIMA(1, 1, 0)x(2, 0, 0, 12)12 - AIC:939.0984778664048
# SARIMA(1, 1, 0)x(2, 0, 1, 12)12 - AIC:940.9087133661069
# SARIMA(1, 1, 0)x(2, 0, 2, 12)12 - AIC:942.2973103071181
# SARIMA(1, 1, 0)x(2, 1, 0, 12)12 - AIC:826.9995808091069
# SARIMA(1, 1, 0)x(2, 1, 1, 12)12 - AIC:823.8261102779344
# SARIMA(1, 1, 0)x(2, 1, 2, 12)12 - AIC:825.0437253090648
# SARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:1262.184006425551
# SARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:1094.3172708640793
# SARIMA(1, 1, 1)x(0, 0, 2, 12)12 - AIC:923.0862224063869
# SARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:1110.62094644005
# SARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:914.0453844988148
# SARIMA(1, 1, 1)x(0, 1, 2, 12)12 - AIC:792.3411370856472
# SARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:1083.393796503136
# SARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:1054.7180547136813
# SARIMA(1, 1, 1)x(1, 0, 2, 12)12 - AIC:916.3549428498841
# SARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:933.2974216823695
# SARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:927.2920638200441
# SARIMA(1, 1, 1)x(1, 1, 2, 12)12 - AIC:794.1929706682694
# SARIMA(1, 1, 1)x(2, 0, 0, 12)12 - AIC:905.9249060843795
# SARIMA(1, 1, 1)x(2, 0, 1, 12)12 - AIC:907.2972867470834
# SARIMA(1, 1, 1)x(2, 0, 2, 12)12 - AIC:900.6725795937009
# SARIMA(1, 1, 1)x(2, 1, 0, 12)12 - AIC:799.9474258320738
# SARIMA(1, 1, 1)x(2, 1, 1, 12)12 - AIC:791.9065436346657
# SARIMA(1, 1, 1)x(2, 1, 2, 12)12 - AIC:783.8990984055157
# SARIMA(1, 1, 2)x(0, 0, 0, 12)12 - AIC:1251.949504070618
# SARIMA(1, 1, 2)x(0, 0, 1, 12)12 - AIC:1085.4861928100897
# SARIMA(1, 1, 2)x(0, 0, 2, 12)12 - AIC:915.4938402270664
# SARIMA(1, 1, 2)x(0, 1, 0, 12)12 - AIC:1096.3571024776702
# SARIMA(1, 1, 2)x(0, 1, 1, 12)12 - AIC:906.4966907626431
# SARIMA(1, 1, 2)x(0, 1, 2, 12)12 - AIC:785.9832738661761
# SARIMA(1, 1, 2)x(1, 0, 0, 12)12 - AIC:1090.7760925259954
# SARIMA(1, 1, 2)x(1, 0, 1, 12)12 - AIC:1042.618321161809
# SARIMA(1, 1, 2)x(1, 0, 2, 12)12 - AIC:906.7535124093873
# SARIMA(1, 1, 2)x(1, 1, 0, 12)12 - AIC:934.8870392438063
# SARIMA(1, 1, 2)x(1, 1, 1, 12)12 - AIC:917.2527818409944
# SARIMA(1, 1, 2)x(1, 1, 2, 12)12 - AIC:787.7843970225863
# SARIMA(1, 1, 2)x(2, 0, 0, 12)12 - AIC:906.1690196543067
# SARIMA(1, 1, 2)x(2, 0, 1, 12)12 - AIC:907.4597827918153
# SARIMA(1, 1, 2)x(2, 0, 2, 12)12 - AIC:896.9408418611488
# SARIMA(1, 1, 2)x(2, 1, 0, 12)12 - AIC:801.9382052142894
# SARIMA(1, 1, 2)x(2, 1, 1, 12)12 - AIC:791.9171139114064
# SARIMA(1, 1, 2)x(2, 1, 2, 12)12 - AIC:776.9401088352404
# SARIMA(1, 1, 3)x(0, 0, 0, 12)12 - AIC:1245.5463125316448
# SARIMA(1, 1, 3)x(0, 0, 1, 12)12 - AIC:1072.9849747216738
# SARIMA(1, 1, 3)x(0, 0, 2, 12)12 - AIC:907.4130105105811
# SARIMA(1, 1, 3)x(0, 1, 0, 12)12 - AIC:1088.0914860025775
# SARIMA(1, 1, 3)x(0, 1, 1, 12)12 - AIC:895.9867971359857
# SARIMA(1, 1, 3)x(0, 1, 2, 12)12 - AIC:780.3059561953239
# SARIMA(1, 1, 3)x(1, 0, 0, 12)12 - AIC:1082.3281487676165
# SARIMA(1, 1, 3)x(1, 0, 1, 12)12 - AIC:1036.1957887554838
# SARIMA(1, 1, 3)x(1, 0, 2, 12)12 - AIC:897.5232291583723
# SARIMA(1, 1, 3)x(1, 1, 0, 12)12 - AIC:936.6664092076053
# SARIMA(1, 1, 3)x(1, 1, 1, 12)12 - AIC:906.7653660425265
# SARIMA(1, 1, 3)x(1, 1, 2, 12)12 - AIC:782.102770457709
# SARIMA(1, 1, 3)x(2, 0, 0, 12)12 - AIC:908.2687609705459
# SARIMA(1, 1, 3)x(2, 0, 1, 12)12 - AIC:909.7955658906905
# SARIMA(1, 1, 3)x(2, 0, 2, 12)12 - AIC:880.2886603344064
# SARIMA(1, 1, 3)x(2, 1, 0, 12)12 - AIC:803.6616207208754
# SARIMA(1, 1, 3)x(2, 1, 1, 12)12 - AIC:795.8367393075682
# SARIMA(1, 1, 3)x(2, 1, 2, 12)12 - AIC:767.5597460912257
# SARIMA(2, 1, 0)x(0, 0, 0, 12)12 - AIC:1280.253756153577
# SARIMA(2, 1, 0)x(0, 0, 1, 12)12 - AIC:1128.7773704711103
# SARIMA(2, 1, 0)x(0, 0, 2, 12)12 - AIC:958.0793208829946
# SARIMA(2, 1, 0)x(0, 1, 0, 12)12 - AIC:1133.2467704396645
# SARIMA(2, 1, 0)x(0, 1, 1, 12)12 - AIC:949.5332566881102
# SARIMA(2, 1, 0)x(0, 1, 2, 12)12 - AIC:827.1933387102839
# SARIMA(2, 1, 0)x(1, 0, 0, 12)12 - AIC:1099.508602157594
# SARIMA(2, 1, 0)x(1, 0, 1, 12)12 - AIC:1076.786319864116
# SARIMA(2, 1, 0)x(1, 0, 2, 12)12 - AIC:951.1988165559607
# SARIMA(2, 1, 0)x(1, 1, 0, 12)12 - AIC:950.2637728228506
# SARIMA(2, 1, 0)x(1, 1, 1, 12)12 - AIC:952.2623518887187
# SARIMA(2, 1, 0)x(1, 1, 2, 12)12 - AIC:828.7198700940803
# SARIMA(2, 1, 0)x(2, 0, 0, 12)12 - AIC:924.6004792645497
# SARIMA(2, 1, 0)x(2, 0, 1, 12)12 - AIC:925.9757801383855
# SARIMA(2, 1, 0)x(2, 0, 2, 12)12 - AIC:927.8380693280782
# SARIMA(2, 1, 0)x(2, 1, 0, 12)12 - AIC:814.2969261795054
# SARIMA(2, 1, 0)x(2, 1, 1, 12)12 - AIC:808.5100914917869
# SARIMA(2, 1, 0)x(2, 1, 2, 12)12 - AIC:810.0074804177934
# SARIMA(2, 1, 1)x(0, 0, 0, 12)12 - AIC:1263.2315231805055
# SARIMA(2, 1, 1)x(0, 0, 1, 12)12 - AIC:1094.2093491949352
# SARIMA(2, 1, 1)x(0, 0, 2, 12)12 - AIC:922.9408472078808
# SARIMA(2, 1, 1)x(0, 1, 0, 12)12 - AIC:1107.1166362359647
# SARIMA(2, 1, 1)x(0, 1, 1, 12)12 - AIC:915.1236479124074
# SARIMA(2, 1, 1)x(0, 1, 2, 12)12 - AIC:794.279962627729
# SARIMA(2, 1, 1)x(1, 0, 0, 12)12 - AIC:1071.4249601101355
# SARIMA(2, 1, 1)x(1, 0, 1, 12)12 - AIC:1052.9244471205288
# SARIMA(2, 1, 1)x(1, 0, 2, 12)12 - AIC:916.2424912822557
# SARIMA(2, 1, 1)x(1, 1, 0, 12)12 - AIC:926.3197036268064
# SARIMA(2, 1, 1)x(1, 1, 1, 12)12 - AIC:928.3197020908631
# SARIMA(2, 1, 1)x(1, 1, 2, 12)12 - AIC:796.1300001391452
# SARIMA(2, 1, 1)x(2, 0, 0, 12)12 - AIC:896.5181608166738
# SARIMA(2, 1, 1)x(2, 0, 1, 12)12 - AIC:897.6399565369617
# SARIMA(2, 1, 1)x(2, 0, 2, 12)12 - AIC:899.4835866285143
# SARIMA(2, 1, 1)x(2, 1, 0, 12)12 - AIC:792.8940753933973
# SARIMA(2, 1, 1)x(2, 1, 1, 12)12 - AIC:784.8928054625017
# SARIMA(2, 1, 1)x(2, 1, 2, 12)12 - AIC:785.8335673005264
# SARIMA(2, 1, 2)x(0, 0, 0, 12)12 - AIC:1253.9102116146673
# SARIMA(2, 1, 2)x(0, 0, 1, 12)12 - AIC:1085.9643552598204
# SARIMA(2, 1, 2)x(0, 0, 2, 12)12 - AIC:916.325831109557
# SARIMA(2, 1, 2)x(0, 1, 0, 12)12 - AIC:1099.4823964821398
# SARIMA(2, 1, 2)x(0, 1, 1, 12)12 - AIC:904.7004130329931
# SARIMA(2, 1, 2)x(0, 1, 2, 12)12 - AIC:784.144313669288
# SARIMA(2, 1, 2)x(1, 0, 0, 12)12 - AIC:1073.2912713694395
# SARIMA(2, 1, 2)x(1, 0, 1, 12)12 - AIC:1044.1909358643477
# SARIMA(2, 1, 2)x(1, 0, 2, 12)12 - AIC:907.6661488802511
# SARIMA(2, 1, 2)x(1, 1, 0, 12)12 - AIC:925.370566841566
# SARIMA(2, 1, 2)x(1, 1, 1, 12)12 - AIC:915.693251087766
# SARIMA(2, 1, 2)x(1, 1, 2, 12)12 - AIC:786.1833874666044
# SARIMA(2, 1, 2)x(2, 0, 0, 12)12 - AIC:897.3464439782516
# SARIMA(2, 1, 2)x(2, 0, 1, 12)12 - AIC:898.3781888403489
# SARIMA(2, 1, 2)x(2, 0, 2, 12)12 - AIC:890.6687981551397
# SARIMA(2, 1, 2)x(2, 1, 0, 12)12 - AIC:794.7799442942787
# SARIMA(2, 1, 2)x(2, 1, 1, 12)12 - AIC:783.7036522800872
# SARIMA(2, 1, 2)x(2, 1, 2, 12)12 - AIC:777.5254055188592
# SARIMA(2, 1, 3)x(0, 0, 0, 12)12 - AIC:1237.8702819333053
# SARIMA(2, 1, 3)x(0, 0, 1, 12)12 - AIC:1067.8073333427924
# SARIMA(2, 1, 3)x(0, 0, 2, 12)12 - AIC:908.3349290654096
# SARIMA(2, 1, 3)x(0, 1, 0, 12)12 - AIC:1089.5369261932872
# SARIMA(2, 1, 3)x(0, 1, 1, 12)12 - AIC:897.1805344810488
# SARIMA(2, 1, 3)x(0, 1, 2, 12)12 - AIC:779.1301959275648
# SARIMA(2, 1, 3)x(1, 0, 0, 12)12 - AIC:1073.452869388287
# SARIMA(2, 1, 3)x(1, 0, 1, 12)12 - AIC:1024.0462155618225
# SARIMA(2, 1, 3)x(1, 0, 2, 12)12 - AIC:890.9483353647388
# SARIMA(2, 1, 3)x(1, 1, 0, 12)12 - AIC:919.0020069315606
# SARIMA(2, 1, 3)x(1, 1, 1, 12)12 - AIC:902.2459021300743
# SARIMA(2, 1, 3)x(1, 1, 2, 12)12 - AIC:780.6508317413305
# SARIMA(2, 1, 3)x(2, 0, 0, 12)12 - AIC:893.3579301578845
# SARIMA(2, 1, 3)x(2, 0, 1, 12)12 - AIC:903.2328170412269
# SARIMA(2, 1, 3)x(2, 0, 2, 12)12 - AIC:879.219181914047
# SARIMA(2, 1, 3)x(2, 1, 0, 12)12 - AIC:792.2339222005022
# SARIMA(2, 1, 3)x(2, 1, 1, 12)12 - AIC:787.8478936256865
# SARIMA(2, 1, 3)x(2, 1, 2, 12)12 - AIC:769.4962085112622
# SARIMA(3, 1, 0)x(0, 0, 0, 12)12 - AIC:1269.8130062641503
# SARIMA(3, 1, 0)x(0, 0, 1, 12)12 - AIC:1119.170315804223
# SARIMA(3, 1, 0)x(0, 0, 2, 12)12 - AIC:953.3440589118029
# SARIMA(3, 1, 0)x(0, 1, 0, 12)12 - AIC:1119.180905601902
# SARIMA(3, 1, 0)x(0, 1, 1, 12)12 - AIC:943.541700933173
# SARIMA(3, 1, 0)x(0, 1, 2, 12)12 - AIC:822.4469311120536
# SARIMA(3, 1, 0)x(1, 0, 0, 12)12 - AIC:1080.5468456727126
# SARIMA(3, 1, 0)x(1, 0, 1, 12)12 - AIC:1065.5569726784663
# SARIMA(3, 1, 0)x(1, 0, 2, 12)12 - AIC:943.6865996304793
# SARIMA(3, 1, 0)x(1, 1, 0, 12)12 - AIC:930.6943146015326
# SARIMA(3, 1, 0)x(1, 1, 1, 12)12 - AIC:932.4901496959708
# SARIMA(3, 1, 0)x(1, 1, 2, 12)12 - AIC:824.1779575724445
# SARIMA(3, 1, 0)x(2, 0, 0, 12)12 - AIC:909.7203197936681
# SARIMA(3, 1, 0)x(2, 0, 1, 12)12 - AIC:911.0620713976473
# SARIMA(3, 1, 0)x(2, 0, 2, 12)12 - AIC:913.0438816472856
# SARIMA(3, 1, 0)x(2, 1, 0, 12)12 - AIC:803.7674514642886
# SARIMA(3, 1, 0)x(2, 1, 1, 12)12 - AIC:794.8634035262477
# SARIMA(3, 1, 0)x(2, 1, 2, 12)12 - AIC:796.636979076378
# SARIMA(3, 1, 1)x(0, 0, 0, 12)12 - AIC:1255.065818070937
# SARIMA(3, 1, 1)x(0, 0, 1, 12)12 - AIC:1095.6894641210008
# SARIMA(3, 1, 1)x(0, 0, 2, 12)12 - AIC:923.887242754735
# SARIMA(3, 1, 1)x(0, 1, 0, 12)12 - AIC:1099.6330865442294
# SARIMA(3, 1, 1)x(0, 1, 1, 12)12 - AIC:915.5227261302047
# SARIMA(3, 1, 1)x(0, 1, 2, 12)12 - AIC:795.1857811462618
# SARIMA(3, 1, 1)x(1, 0, 0, 12)12 - AIC:1064.6149136508604
# SARIMA(3, 1, 1)x(1, 0, 1, 12)12 - AIC:1046.0837554344873
# SARIMA(3, 1, 1)x(1, 0, 2, 12)12 - AIC:917.0308009384253
# SARIMA(3, 1, 1)x(1, 1, 0, 12)12 - AIC:914.5580669318421
# SARIMA(3, 1, 1)x(1, 1, 1, 12)12 - AIC:916.4809813444103
# SARIMA(3, 1, 1)x(1, 1, 2, 12)12 - AIC:796.8065566403687
# SARIMA(3, 1, 1)x(2, 0, 0, 12)12 - AIC:887.3204459898275
# SARIMA(3, 1, 1)x(2, 0, 1, 12)12 - AIC:888.327920853794
# SARIMA(3, 1, 1)x(2, 0, 2, 12)12 - AIC:890.1571522292563
# SARIMA(3, 1, 1)x(2, 1, 0, 12)12 - AIC:785.3678771490232
# SARIMA(3, 1, 1)x(2, 1, 1, 12)12 - AIC:777.3603962370714
# SARIMA(3, 1, 1)x(2, 1, 2, 12)12 - AIC:777.5853448601772
# SARIMA(3, 1, 2)x(0, 0, 0, 12)12 - AIC:1255.9835656170883
# SARIMA(3, 1, 2)x(0, 0, 1, 12)12 - AIC:1086.7092406513336
# SARIMA(3, 1, 2)x(0, 0, 2, 12)12 - AIC:917.7980110375426
# SARIMA(3, 1, 2)x(0, 1, 0, 12)12 - AIC:1097.5317771851276
# SARIMA(3, 1, 2)x(0, 1, 1, 12)12 - AIC:906.5708112001819
# SARIMA(3, 1, 2)x(0, 1, 2, 12)12 - AIC:787.9521880853024
# SARIMA(3, 1, 2)x(1, 0, 0, 12)12 - AIC:1066.2776211356445
# SARIMA(3, 1, 2)x(1, 0, 1, 12)12 - AIC:1046.4637249323423
# SARIMA(3, 1, 2)x(1, 0, 2, 12)12 - AIC:909.2875129120447
# SARIMA(3, 1, 2)x(1, 1, 0, 12)12 - AIC:915.6058910028602
# SARIMA(3, 1, 2)x(1, 1, 1, 12)12 - AIC:917.409145832214
# SARIMA(3, 1, 2)x(1, 1, 2, 12)12 - AIC:789.5119881126537
# SARIMA(3, 1, 2)x(2, 0, 0, 12)12 - AIC:893.4586714047508
# SARIMA(3, 1, 2)x(2, 0, 1, 12)12 - AIC:890.3277441260019
# SARIMA(3, 1, 2)x(2, 0, 2, 12)12 - AIC:896.3264738455684
# SARIMA(3, 1, 2)x(2, 1, 0, 12)12 - AIC:786.7471041590937
# SARIMA(3, 1, 2)x(2, 1, 1, 12)12 - AIC:777.261621491905
# SARIMA(3, 1, 2)x(2, 1, 2, 12)12 - AIC:778.7263090651878
# SARIMA(3, 1, 3)x(0, 0, 0, 12)12 - AIC:1243.738641069618
# SARIMA(3, 1, 3)x(0, 0, 1, 12)12 - AIC:1060.5398147577464
# SARIMA(3, 1, 3)x(0, 0, 2, 12)12 - AIC:910.3349186410923
# SARIMA(3, 1, 3)x(0, 1, 0, 12)12 - AIC:1090.4366088641052
# SARIMA(3, 1, 3)x(0, 1, 1, 12)12 - AIC:899.800355358014
# SARIMA(3, 1, 3)x(0, 1, 2, 12)12 - AIC:780.7435476763279
# SARIMA(3, 1, 3)x(1, 0, 0, 12)12 - AIC:1069.991409045567
# SARIMA(3, 1, 3)x(1, 0, 1, 12)12 - AIC:1039.7662380707898
# SARIMA(3, 1, 3)x(1, 0, 2, 12)12 - AIC:900.0483834692005
# SARIMA(3, 1, 3)x(1, 1, 0, 12)12 - AIC:919.3449748861267
# SARIMA(3, 1, 3)x(1, 1, 1, 12)12 - AIC:907.6982326682811
# SARIMA(3, 1, 3)x(1, 1, 2, 12)12 - AIC:782.5628096361241
# SARIMA(3, 1, 3)x(2, 0, 0, 12)12 - AIC:884.0463711762559
# SARIMA(3, 1, 3)x(2, 0, 1, 12)12 - AIC:886.0759651128978
# SARIMA(3, 1, 3)x(2, 0, 2, 12)12 - AIC:880.559571585516
# SARIMA(3, 1, 3)x(2, 1, 0, 12)12 - AIC:785.6197788366087
# SARIMA(3, 1, 3)x(2, 1, 1, 12)12 - AIC:780.2648852199086
# SARIMA(3, 1, 3)x(2, 1, 2, 12)12 - AIC:772.3350753612622

# %%
SARIMA_AIC.sort_values(by=['AIC']).head(2)
# Out:
#          param       seasonal         AIC
# 71   (0, 1, 3)  (2, 1, 2, 12)  767.224375
# 143  (1, 1, 3)  (2, 1, 2, 12)  767.559746

# %%
import statsmodels.api as sm

model = sm.tsa.statespace.SARIMAX(train['Rose'].values,
                                order=(0, 1, 3),
                                seasonal_order=(2, 1, 2, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results_SARIMA = model.fit()
print(results_SARIMA.summary())
# Out:
#                                         SARIMAX Results
# ===============================================================================================
# Dep. Variable:                                       y   No. Observations:                  132
# Model:             SARIMAX(0, 1, 3)x(2, 1, [1, 2], 12)   Log Likelihood                -375.612
# Date:                                 Mon, 28 Jun 2021   AIC                            767.224
# Time:                                         15:32:10   BIC                            787.311
# Sample:                                              0   HQIC                           775.328
#                                                  - 132
# Covariance Type:                                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.9817      0.190     -5.175      0.000      -1.353      -0.610
# ma.L2         -0.0472      0.176     -0.268      0.789      -0.392       0.298
# ma.L3         -0.0043      0.131     -0.033      0.974      -0.260       0.252
# ar.S.L12       0.0637      0.158      0.405      0.686      -0.245       0.372
# ar.S.L24      -0.0502      0.045     -1.110      0.267      -0.139       0.038
# ma.S.L12      -0.7987      0.362     -2.203      0.028      -1.509      -0.088
# ma.S.L24      -0.0784      0.200     -0.393      0.694      -0.469       0.313
# sigma2       178.0501     52.573      3.387      0.001      75.008     281.092
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 5.49
# Prob(Q):                              0.94   Prob(JB):                         0.06
# Heteroskedasticity (H):               0.93   Skew:                             0.42
# Prob(H) (two-sided):                  0.84   Kurtosis:                         3.85
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
#get the predictions and residuals
predictions = results_SARIMA.get_forecast(steps=len(test))

# %%
SARIMA_RMSE = metrics.mean_squared_error(test['Rose'],predictions.predicted_mean,squared=False)

print("AutoSARIMA Model(least AIC)(0,1,3)(2,1,2,12):, RMSE is %3.2f" 
      %(SARIMA_RMSE))
# Out:
# AutoSARIMA Model(least AIC)(0,1,3)(2,1,2,12):, RMSE is 16.67

# %%
#store the RMSE details in the table
tempResultsDf= pd.DataFrame({'Model': 'AutoSARIMA Model(least AIC)(0,1,3)(2,1,2,12)', 'WineType':['Rose'],
                              'Test_RMSE': SARIMA_RMSE})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# # Model 14 & 15: ARIMA & SARIMA models based on the cut-off points of ACF & PACF

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
from matplotlib.pyplot import figure
import statsmodels.api as sm
import statsmodels.tsa.api as smt
import statsmodels.formula.api as smf

# %% [markdown]
# ## ACF & PACF

# %% [markdown]
# A nonseasonal ARIMA model is classified as an "ARIMA(p,d,q)" model, where:
#
# - p is the number of autoregressive terms,
# - d is the number of nonseasonal differences needed for stationarity, and
# - q is the number of lagged forecast errors in the prediction equation.
#
# Now, the question is how to find out these values based on ACF and PACF graph.

# %% [markdown]
# ### Original Series

# %%
# ACF and PACF with original time series
fig, axes = plt.subplots(1, 2)
fig.set_figwidth(12)
fig.set_figheight(4)
smt.graphics.plot_acf(train, lags=50, ax=axes[0],
                      title='Rose Wine: Autocorrelation')
smt.graphics.plot_pacf(train, lags=50, ax=axes[1],
                       title='Rose Wine: Partial Autocorrelation')
plt.tight_layout()

# %% [markdown]
# Here, we could see very less PACF and ACF has significant correlation at lag 1 but after that it is decaying and becoming insignificant.
#
# Hence, try differencing the order using d = 1 and try to evaluate ACF and PACF again.

# %% [markdown]
# ### Differenced Time series with (d = 1)

# %%
# ACF with order difference as "1" as the series was not stationary (refer stationary point#5)
fig, axes = plt.subplots(1, 2)
fig.set_figwidth(12)
fig.set_figheight(4)
smt.graphics.plot_acf(train.diff().dropna(), lags=15, ax=axes[0],
                      title='Rose Wine: Differenced Series Autocorrelation (ACF)')
smt.graphics.plot_pacf(train.diff().dropna(), lags=15, ax=axes[1],
                       title='Rose Wine: Differenced Series Partial Autocorrelation (PACF)')
plt.tight_layout()

# %% [markdown]
# ## ARIMA Model

# %% [markdown]
# Based on graph, let's evaluate p and q value.
#
# Here, we have taken alpha=0.05.
#
# - The Auto-Regressive parameter in an ARIMA model is 'p' which comes from the significant lag before which the PACF plot cuts-off to 0.
# - The Moving-Average parameter in an ARIMA model is 'q' which comes from the significant lag before the ACF plot cuts-off to 0.
#
# By looking at the above plots, we will take the value of p and q to be 2 and 2 respectively.
#
# __Hence, let's take ACF(q)(MA) value as 2 and PACF(p)(AR) value as 2__

# %%
# p = 2 , d = 1 and q = 2

# %% [markdown]
# ### ARIMA(2,1,2)

# %%
model_manual = ARIMA(train, order=(2,1,2),freq="MS")

results_manual_arima = model_manual.fit()

print(results_manual_arima.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   Rose   No. Observations:                  132
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                -635.935
# Date:                Mon, 28 Jun 2021   AIC                           1281.871
# Time:                        15:32:11   BIC                           1296.247
# Sample:                    01-01-1980   HQIC                          1287.712
#                          - 12-01-1990
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4540      0.469     -0.969      0.333      -1.372       0.464
# ar.L2          0.0001      0.170      0.001      0.999      -0.334       0.334
# ma.L1         -0.2541      0.459     -0.554      0.580      -1.154       0.646
# ma.L2         -0.5984      0.430     -1.390      0.164      -1.442       0.245
# sigma2       952.1601     91.424     10.415      0.000     772.973    1131.347
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                34.16
# Prob(Q):                              0.88   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.37   Skew:                             0.79
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.94
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# Here we could see two main things:
#
# - P values at all lags are significant (i.e. P value is less then 0.05)
# - coeff value are not summing up to 1 Which means there is no sign of a "unit root" because the sum of the ARA coefficients is not close to -1
#
# Hence, ARIMA (2,1,2) is On the whole, this appears to be a good model.

# %%
#get prediction start and end dates
pred_start_date = test.index[0]
pred_end_date = test.index[-1]

#get the predictions and residuals
predictions = results_manual_arima.predict(start=pred_start_date, end=pred_end_date)
residuals = test['Rose'] - predictions

# %%
ARIMA_Manual_RMSE = metrics.mean_squared_error(test['Rose'],predictions,squared=False)

print("ManualARIMA Model(ACF-PACF)(2,1,2):, RMSE is %3.2f" 
      %(ARIMA_Manual_RMSE))
# Out:
# ManualARIMA Model(ACF-PACF)(2,1,2):, RMSE is 36.89

# %%
#store the RMSE details in the table
tempResultsDf= pd.DataFrame({'Model': 'ManualARIMA Model(ACF-PACF)(2,1,2)', 'WineType':['Rose'],
                              'Test_RMSE': ARIMA_Manual_RMSE})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# ### SARIMA Model

# %% [markdown]
# Let's have a look on the ACF and the PACF plots one more time.

# %% [markdown]
# #### ACF and PACF (differenced d = 1)

# %%
# ACF with order difference as "1" as the series was not stationary (refer stationary point#5)
fig, axes = plt.subplots(1, 2)
fig.set_figwidth(12)
fig.set_figheight(4)
smt.graphics.plot_acf(train.diff().dropna(), lags=50, ax=axes[0],
                      title='Rose Wine: Differenced Series Autocorrelation (ACF)')
smt.graphics.plot_pacf(train.diff().dropna(), lags=50, ax=axes[1],
                       title='Rose Wine: Differenced Series Partial Autocorrelation (PACF)')
plt.tight_layout()

# %% [markdown]
# We could see that ACF plot at the seasonal interval (i.e. 12) does not taper off. So, now we take a seasonal differencing and check the series

# %% [markdown]
# #### ACF and PACF Seasonal differece(12)

# %%
(train.diff(12)).plot(figsize=(14,6))
plt.grid();

# %% [markdown]
# We see that there might be a slight trend which can be noticed in the data. So we take a differencing of first order on the seasonally differenced series.

# %% [markdown]
# Let us go ahead and check the stationarity of the above series before fitting the SARIMA model.

# %%
dftest = adfuller(train.diff(12).dropna(),regression='ct')
print('DF test statistic is %3.3f' %dftest[0])
print('DF test p-value is' ,dftest[1])
print('Number of lags used' ,dftest[2])
# Out:
# DF test statistic is -4.247
# DF test p-value is 0.003801400954820934
# Number of lags used 11

# %% [markdown]
# The series is stationary. Let's check the ACF and the PACF plots for the new modified Time Series.

# %%
# ACF with seasonal difference as "12"
fig, axes = plt.subplots(1, 2)
fig.set_figwidth(12)
fig.set_figheight(4)
smt.graphics.plot_acf(train.diff(12).dropna(), lags=15, ax=axes[0],
                      title='Rose Wine: Seasonal Difference Series Autocorrelation (ACF)')
smt.graphics.plot_pacf(train.diff(12).dropna(), lags=15, ax=axes[1],
                       title='Rose Wine: Seasonal Difference Series Partial Autocorrelation (PACF)')
plt.tight_layout()

# %% [markdown]
# Here, we have taken alpha=0.05.
#
# We are going to take the seasonal period as 12.
# We will keep the p(2) and q(2) parameters same as the ARIMA model.
#
# - The Auto-Regressive parameter in an SARIMA model is 'P' which comes from the significant lag after which the PACF plot cuts-off to 0.
# - The Moving-Average parameter in an SARIMA model is 'Q' which comes from the significant lag after which the ACF plot cuts-off to 0.
#
# Remember to check the ACF and the PACF plots only at multiples of 12 (since 12 is the seasonal period).
#
# By looking at the plots we see that both the ACF and the PACF cuts-off after lag 1. Remember, here we are considering the seasonal lags.

# %%
# p = 2, d = 1, q = 2
# P = 1, D = 1, Q = 1 F = 12

# %%
manual_SARIMA = sm.tsa.statespace.SARIMAX(train,
                                order=(2, 1, 2),
                                seasonal_order=(1, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results_manual_SARIMA = manual_SARIMA.fit()
print(results_manual_SARIMA.summary())
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                 Rose   No. Observations:                  132
# Model:             SARIMAX(2, 1, 2)x(1, 1, [1], 12)   Log Likelihood                -450.847
# Date:                              Mon, 28 Jun 2021   AIC                            915.693
# Time:                                      15:32:13   BIC                            934.204
# Sample:                                  01-01-1980   HQIC                           923.192
#                                        - 12-01-1990
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.1034      0.133      8.286      0.000       0.842       1.364
# ar.L2         -0.3436      0.109     -3.150      0.002      -0.557      -0.130
# ma.L1         -1.8152      0.105    -17.288      0.000      -2.021      -1.609
# ma.L2          0.8668      0.093      9.275      0.000       0.684       1.050
# ar.S.L12      -0.3877      0.069     -5.625      0.000      -0.523      -0.253
# ma.S.L12      -0.0788      0.130     -0.605      0.545      -0.334       0.176
# sigma2       338.2792     53.802      6.287      0.000     232.829     443.729
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.25   Jarque-Bera (JB):                 0.03
# Prob(Q):                              0.62   Prob(JB):                         0.98
# Heteroskedasticity (H):               0.66   Skew:                             0.04
# Prob(H) (two-sided):                  0.22   Kurtosis:                         2.97
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
#get prediction start and end dates
pred_start_date = test.index[0]
pred_end_date = test.index[-1]

#get the predictions and residuals
predictions = results_manual_SARIMA.predict(start=pred_start_date, end=pred_end_date)
residuals = test['Rose'] - predictions

# %%
SARIMA_Manual_RMSE = metrics.mean_squared_error(test['Rose'],predictions,squared=False)

print("ManualSARIMA Model(ACF-PACF)(2,1,2)(1,1,1,12):, RMSE is %3.2f" 
      %(SARIMA_Manual_RMSE))
# Out:
# ManualSARIMA Model(ACF-PACF)(2,1,2)(1,1,1,12):, RMSE is 13.27

# %%
#store the RMSE details in the table
tempResultsDf= pd.DataFrame({'Model': 'ManualSARIMA Model(ACF-PACF)(2,1,2)(1,1,1,12)', 'WineType':['Rose'],
                              'Test_RMSE': SARIMA_Manual_RMSE})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# # Table with All Models
# __(corresponding parameters and test RMSE value)__

# %% [markdown]
# At the time of model creation and evaluation we have stored model details with its parameters, type of wine and test RMSE value

# %%
# this is the final table which has all the model stored with sorted with least RMSE value.
resultsDf
# Out:
#                                            Model WineType  Test_RMSE
# 0  ManualSARIMA Model(ACF-PACF)(2,1,2)(1,1,1,12)     Rose  13.269988
# 0                          moving_avg_forecast_3     Rose  14.129000
# 0       TES(Holt_Winter)-Add(L:0.09,T:0.0,S:0.0)     Rose  14.295361
# 0                          moving_avg_forecast_4     Rose  14.457000
# 0                          moving_avg_forecast_5     Rose  14.481000
# 0                 DES(least RMSE)(L:0.04,T:0.47)     Rose  14.566308
# 0                          moving_avg_forecast_6     Rose  14.572000
# 0                          moving_avg_forecast_8     Rose  14.803000
# 0                         moving_avg_forecast_12     Rose  15.239000
# 0                  DES(Holt_linear)(L:0.0,T:0.0)     Rose  15.276707
# 0   AutoSARIMA Model(least AIC)(0,1,3)(2,1,2,12)     Rose  16.673252
# 0      TES(Holt_Winter)-Mul(L:0.06,T:0.05,S:0.0)     Rose  21.285869
# 0                        SES(least RMSE)(L:0.07)     Rose  36.459396
# 0              AutoARIMA Model(least AIC)(2,1,3)     Rose  36.837514
# 0             ManualARIMA Model(ACF-PACF)(2,1,2)     Rose  36.894783
# 0                                 Simple Average     Rose  53.484000
# 0                               RegressionOnTime     Rose  71.617000
# 0                       RegressionOnTimeSeasonal     Rose  73.425000
# 0                                    Naive model     Rose  79.741000

# %% [markdown]
# Around total of 15 models we have build for "Rose Wine" dataset and the best model which is coming out is
#
# __SARIMA Model (ACF and PACF) with parameters (p=2,d=1,q=2)(P=1,D=1,Q=1,F=12) and test RMSE value ~13__
#
# Now, we will take this model and forecast 12 months into the future with appropriate confidence intervals to see how the predictions look. We have to build our model on the full data for this.

# %% [markdown]
# # Run the best model (Manual SARIMA) on full dataset and predict 12 months into the future with appropriate confidence intervals/bands

# %% [markdown]
# Here, we have both training and full data both were non-stationary hence, nothing to be done in terms of stationarity.

# %% [markdown]
# ## Run best model with fulldata

# %%
model_fulldata = sm.tsa.statespace.SARIMAX(df,
                                order=(2,1,2),
                                seasonal_order=(1, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results_model_fulldata = model_fulldata.fit()
print(results_model_fulldata.summary())
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                 Rose   No. Observations:                  187
# Model:             SARIMAX(2, 1, 2)x(1, 1, [1], 12)   Log Likelihood                -665.357
# Date:                              Mon, 28 Jun 2021   AIC                           1344.714
# Time:                                      15:32:14   BIC                           1366.197
# Sample:                                  01-01-1980   HQIC                          1353.438
#                                        - 07-01-1995
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.1076      0.093     11.896      0.000       0.925       1.290
# ar.L2         -0.3258      0.080     -4.096      0.000      -0.482      -0.170
# ma.L1         -1.8277      0.068    -27.021      0.000      -1.960      -1.695
# ma.L2          0.8784      0.060     14.602      0.000       0.760       0.996
# ar.S.L12      -0.3825      0.049     -7.748      0.000      -0.479      -0.286
# ma.S.L12      -0.0859      0.093     -0.922      0.357      -0.268       0.097
# sigma2       251.0878     26.981      9.306      0.000     198.206     303.970
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.38   Jarque-Bera (JB):                 2.95
# Prob(Q):                              0.54   Prob(JB):                         0.23
# Heteroskedasticity (H):               0.22   Skew:                             0.04
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
results_model_fulldata.plot_diagnostics();

# %% [markdown]
# ## Forcest for next 12 months with confidence intervals

# %%
prediction_nxt12mnths = results_model_fulldata.get_forecast(steps=12)

# %%
prediction_nxt12mnths.summary_frame(alpha=0.05)
# Out:
# Rose             mean    mean_se  mean_ci_lower  mean_ci_upper
# 1995-08-01  52.903052  15.845750      21.845953      83.960151
# 1995-09-01  47.575612  16.454674      15.325045      79.826180
# 1995-10-01  52.335140  16.463905      20.066480      84.603800
# 1995-11-01  57.442749  16.463936      25.174026      89.711471
# 1995-12-01  82.696318  16.474391      50.407106     114.985530
# 1996-01-01  31.828066  16.539195      -0.588161      64.244293
# 1996-02-01  39.321502  16.689000       6.611664      72.031339
# 1996-03-01  45.945160  16.921723      12.779193      79.111128
# 1996-04-01  52.306244  17.216637      18.562256      86.050233
# 1996-05-01  37.754561  17.550187       3.356827      72.152296
# 1996-06-01  45.123998  17.903679      10.033431      80.214564
# 1996-07-01  57.110691  18.264742      21.312454      92.908927

# %%
RMSE_fulldata = metrics.mean_squared_error(df['Rose'],results_model_fulldata.fittedvalues,squared=False)

print("ManualSARIMA Model(ACF-PACF)(2,1,2)(1,1,1,12):, RMSE is %3.2f" 
      %(RMSE_fulldata))
# Out:
# ManualSARIMA Model(ACF-PACF)(2,1,2)(1,1,1,12):, RMSE is 38.73

# %%
pred_full_manual_SARIMA_date = prediction_nxt12mnths.summary_frame(alpha=0.05).set_index(pd.date_range(start='1995-08-01',end='1996-07-01', freq='MS'))

# %%
# plot the forecast along with the confidence band

axis = df['Rose'].plot(label='Actual')
pred_full_manual_SARIMA_date['mean'].plot(ax=axis, label='Forecast', alpha=0.7,figsize=(20,6))
axis.fill_between(pred_full_manual_SARIMA_date.index, pred_full_manual_SARIMA_date['mean_ci_lower'], 
                  pred_full_manual_SARIMA_date['mean_ci_upper'], color='black', alpha=.15)
axis.set_xlabel('Year-Months')
axis.set_ylabel('Sales: Rose Wine')
plt.legend(loc='best')
plt.grid();

# %% [markdown]
# # Comment on the model thus built and report your findings and suggest the measures that the company should be taking for future sales

# %% [markdown]
# ## Key Findings:

# %% [markdown]
# __Plot diagnostics summary charts__ gives promising result and below are point that justifies the same.
#
# - (Top left chart): Residual chart says it is ranges between 4 to -2 which is good. The residuals over time don't display any obvious seasonality and appear to be white noise.
#
# - (Bottom right chart): This is confirmed by the autocorrelation (i.e. correlogram) plot, which shows that the time series residuals have low correlation with lagged versions of itself. Autocorrelation (correlogram) plot of the residuals doesn't show the unexplained correlation which is left in the data.
#
# - (Bottom left chart): QQ (Normaluity) plot have the linear relationship. Further, it shows that the ordered distribution of residuals (blue dots) follows the linear trend of the samples taken from a standard normal distribution with N(0, 1). Again, this is a strong indication that the residuals are normally distributed.
#
# - (Top right chart): Distribution plot is seems to be normal with mean 0 and std as 1 with in no real outliers.
#
# So, Overall we can conclude that that residuals are random with no information or juice in them and our model produces a satisfactory fit that could help us understand our time series data and forecast future values.

# %% [markdown]
# ## Business Recommendations:

# %% [markdown]
# Time series forecasting helps businesses make informed business decisions because it can be based on historical data patterns. It can be used to forecast future conditions and events. mentioned below are four key characteristics which time series forecasting has.
#
# __Reliability:__ Time series forecasting is most reliable, especially when the data represents a broad time period such as large numbers of observations for longer time periods. Information can be extracted by measuring data at various intervals.
#
# __Seasonal patterns:__ Data points variances measured can reveal seasonal fluctuation patterns that serve as the basis for forecasts. Such information is of particular importance to markets whose products fluctuate seasonally because it helps them plan for production and delivery requirements.
#
# __Trend estimation:__ Time series method can also be used to identify trends because data tendencies from it can be useful to managers when measurements show a decrease or an increase in sales for a particular product.
#
# __Growth:__ Time series method is useful to measure both endogenous and financial growth. Endogenous growth is the development from within an organization’s internal human capital that leads to economic growth. For example, the impact of policy variables can be evidenced through time series analysis.
#
# Based on the Rose Wine dataset, it is coming out that this timeseries has __declining trend and seasonality(~80% of the sale is coming from last qtr that is Oct to Dec.)Further,there are certain spikes across the months mainly in Jul to Sep and Dec.__.
#
# According to us, mentioned below are the __ways through which we could manage the business seasonality__.
#
# - Look for ways to diversify: e can offset seasonality by being as innovative as possible. Whether that means diversifying product lines or by pre-empting what your customers want. Market survery is the best way to understand the business/customer needs.
#
# - Develop sales, inventory and staffing plans: Planning inventory and sales at least six months ahead will helps pinpoint where business needs to build in a cash cushion to tide over during quieter periods. Plan everything from stock levels to staff. That way business have the supplies and all material required when demand picks up again. A cash flow forecast can also help with this.
#
# - Think ahead, how will this new seasonal business develop? Will it simply become an addition to your current business, or has it got strong enough legs to stand on its own?

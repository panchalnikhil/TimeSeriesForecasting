# %% [markdown]
# __Problem Statement:__
#
# For this particular assignment, the data of different types of wine sales in the 20th century is to be analysed. Both of these data are from the same company but of different wines. As an analyst in the ABC Estate Wines, you are tasked to analyse and forecast Wine Sales in the 20th century.
#
# Dataset for the Problem: `'Sparkling.csv'`
#
# Please do perform the __following questions__ on each of these __two datasets separately__.
#
# 1. Read the data as an appropriate __Time Series data and plot the data__. (3 points)
# 2. Perform appropriate __Exploratory Data Analysis__ to understand the data and also __perform decomposition__. (4 points)
# 3. Split the data into __training and test__. The _test data should start in 1991_. (3 points)
# 4. Build various __exponential smoothing models__ on the training data and __evaluate the model using RMSE on the test data__. Other models such as __regression,naïve forecast models, simple average models etc.__ should also be built on the training data and check the performance on the test data using RMSE. (13 points)
# 5. Check for the __stationarity of the data__ on which the model is being built on using appropriate statistical tests and also mention the hypothesis for the statistical test. If the data is found __to be non-stationary, take appropriate steps to make it stationary__. Check the new data for stationarity and comment. Note: Stationarity should be checked at alpha = 0.05. (4 points)
# 6. Build an __automated version of the ARIMA/SARIMA model in which the parameters are selected using the lowest Akaike Information Criteria (AIC)__ on the training data and evaluate this model on the __test data using RMSE__. (7 points)
# 7. Build __ARIMA/SARIMA models based on the cut-off points of ACF and PACF__ on the training data and evaluate this model on the test data using RMSE. (6 points)
# 8. Build __a table with all the models built along with their corresponding parameters__ and the __respective RMSE values on the test data__. (3 points)
# 9. Based on __the model-building exercise__, build __the most optimum model(s) on the complete data and predict 12 months into the future with appropriate confidence intervals/bands__. (3 points)
# 10. Comment on __the model thus built and report your findings__ and __suggest the measures that the company should be taking for future sales__. (4 points)

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#LOAD-THE-DATASETS" data-toc-modified-id="LOAD-THE-DATASETS-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>LOAD THE DATASETS</a></span><ul class="toc-item"><li><span><a href="#Import-Libraries" data-toc-modified-id="Import-Libraries-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Import Libraries</a></span></li><li><span><a href="#Read-the-time-series-datasets-and-plot-the-graph" data-toc-modified-id="Read-the-time-series-datasets-and-plot-the-graph-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Read the time-series datasets and plot the graph</a></span></li></ul></li><li><span><a href="#Exploratory-Data-Analysis-&amp;-Decomposition" data-toc-modified-id="Exploratory-Data-Analysis-&amp;-Decomposition-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Exploratory Data Analysis &amp; Decomposition</a></span><ul class="toc-item"><li><span><a href="#Exploratory-Data-Analysis-(EDA)" data-toc-modified-id="Exploratory-Data-Analysis-(EDA)-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Exploratory Data Analysis (EDA)</a></span><ul class="toc-item"><li><span><a href="#Missing-data-check" data-toc-modified-id="Missing-data-check-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Missing data check</a></span></li><li><span><a href="#Basic-measure-of-Descriptive-Statistics" data-toc-modified-id="Basic-measure-of-Descriptive-Statistics-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Basic measure of Descriptive Statistics</a></span></li><li><span><a href="#Plot-a-year-on-year-boxplot" data-toc-modified-id="Plot-a-year-on-year-boxplot-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Plot a year on year boxplot</a></span></li><li><span><a href="#Plot-a-monthly-boxplot-by-taking-all-the-years-into-account" data-toc-modified-id="Plot-a-monthly-boxplot-by-taking-all-the-years-into-account-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Plot a monthly boxplot by taking all the years into account</a></span></li><li><span><a href="#Plot-a-monthplot-of-the-given-time-series" data-toc-modified-id="Plot-a-monthplot-of-the-given-time-series-2.1.5"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>Plot a monthplot of the given time series</a></span></li><li><span><a href="#Plot-the-Time-Series-according-to-different-months-for-different-years" data-toc-modified-id="Plot-the-Time-Series-according-to-different-months-for-different-years-2.1.6"><span class="toc-item-num">2.1.6&nbsp;&nbsp;</span>Plot the Time Series according to different months for different years</a></span></li><li><span><a href="#Lag-plot" data-toc-modified-id="Lag-plot-2.1.7"><span class="toc-item-num">2.1.7&nbsp;&nbsp;</span>Lag plot</a></span></li></ul></li><li><span><a href="#Decompose-the-Time-Series" data-toc-modified-id="Decompose-the-Time-Series-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Decompose the Time Series</a></span><ul class="toc-item"><li><span><a href="#Additive-Decomposition" data-toc-modified-id="Additive-Decomposition-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Additive Decomposition</a></span></li><li><span><a href="#Multiplicative-Decomposition" data-toc-modified-id="Multiplicative-Decomposition-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Multiplicative Decomposition</a></span></li></ul></li></ul></li><li><span><a href="#Train---Test-Split" data-toc-modified-id="Train---Test-Split-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Train - Test Split</a></span></li><li><span><a href="#Model-Building-using-various-Time-series-techniques" data-toc-modified-id="Model-Building-using-various-Time-series-techniques-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Model Building using various Time series techniques</a></span><ul class="toc-item"><li><span><a href="#Model-1:-Regression-on-Time" data-toc-modified-id="Model-1:-Regression-on-Time-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Model 1: Regression on Time</a></span></li><li><span><a href="#Model-2:-Regression-on-Time-With-Seasonal-Components" data-toc-modified-id="Model-2:-Regression-on-Time-With-Seasonal-Components-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Model 2: Regression on Time With Seasonal Components</a></span></li><li><span><a href="#Model-3:-Naive-Approach:--𝑦̂-𝑡+1=𝑦𝑡" data-toc-modified-id="Model-3:-Naive-Approach:--𝑦̂-𝑡+1=𝑦𝑡-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Model 3: Naive Approach:  𝑦̂ 𝑡+1=𝑦𝑡</a></span></li><li><span><a href="#Model-4:-Simple-Average" data-toc-modified-id="Model-4:-Simple-Average-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Model 4: Simple Average</a></span></li><li><span><a href="#Model-5:-Moving-Average(MA)" data-toc-modified-id="Model-5:-Moving-Average(MA)-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Model 5: Moving Average(MA)</a></span></li><li><span><a href="#Model-6:-Simple-Exponential-Smoothing-(SES)" data-toc-modified-id="Model-6:-Simple-Exponential-Smoothing-(SES)-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Model 6: Simple Exponential Smoothing (SES)</a></span></li><li><span><a href="#Model-7:-SES-model---Best-alpha-with-least-RMSE" data-toc-modified-id="Model-7:-SES-model---Best-alpha-with-least-RMSE-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Model 7: SES model - Best alpha with least RMSE</a></span></li><li><span><a href="#Model-8:-Holt's-Linear-Trend-Method-(Double-Exponential-Smoothing)" data-toc-modified-id="Model-8:-Holt's-Linear-Trend-Method-(Double-Exponential-Smoothing)-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Model 8: Holt's Linear Trend Method (Double Exponential Smoothing)</a></span></li><li><span><a href="#Model-9:-DES-model---Best-alpha-and-beta-with-least-RMSE" data-toc-modified-id="Model-9:-DES-model---Best-alpha-and-beta-with-least-RMSE-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Model 9: DES model - Best alpha and beta with least RMSE</a></span></li><li><span><a href="#Model-10:-Holt-Winters-Method---Additive-seasonality" data-toc-modified-id="Model-10:-Holt-Winters-Method---Additive-seasonality-4.10"><span class="toc-item-num">4.10&nbsp;&nbsp;</span>Model 10: Holt-Winters Method - Additive seasonality</a></span></li><li><span><a href="#Model-11:-Holt-Winters-Method---Multiplicative-seasonality" data-toc-modified-id="Model-11:-Holt-Winters-Method---Multiplicative-seasonality-4.11"><span class="toc-item-num">4.11&nbsp;&nbsp;</span>Model 11: Holt-Winters Method - Multiplicative seasonality</a></span></li></ul></li><li><span><a href="#Check-for-stationarity-on-Time-Series-data-(Full-data-&amp;-Train-data)." data-toc-modified-id="Check-for-stationarity-on-Time-Series-data-(Full-data-&amp;-Train-data).-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Check for stationarity on Time Series data (Full data &amp; Train data).</a></span><ul class="toc-item"><li><span><a href="#ADF-Test" data-toc-modified-id="ADF-Test-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>ADF Test</a></span></li><li><span><a href="#Convert-Non-stationary-to-Stationary" data-toc-modified-id="Convert-Non-stationary-to-Stationary-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Convert Non-stationary to Stationary</a></span></li></ul></li><li><span><a href="#Model-12-&amp;-13:-Automated-version-of-ARIMA-&amp;-SARIMA-model-with-least-AIC-(Akaike-Information-Criteria)-value" data-toc-modified-id="Model-12-&amp;-13:-Automated-version-of-ARIMA-&amp;-SARIMA-model-with-least-AIC-(Akaike-Information-Criteria)-value-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Model 12 &amp; 13: Automated version of ARIMA &amp; SARIMA model with least AIC (Akaike Information Criteria) value</a></span><ul class="toc-item"><li><span><a href="#ARIMA-Model" data-toc-modified-id="ARIMA-Model-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>ARIMA Model</a></span></li><li><span><a href="#SARIMA-Model" data-toc-modified-id="SARIMA-Model-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>SARIMA Model</a></span></li></ul></li><li><span><a href="#Model-14-&amp;-15:-ARIMA-&amp;-SARIMA-models-based-on-the-cut-off-points-of-ACF-&amp;-PACF" data-toc-modified-id="Model-14-&amp;-15:-ARIMA-&amp;-SARIMA-models-based-on-the-cut-off-points-of-ACF-&amp;-PACF-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Model 14 &amp; 15: ARIMA &amp; SARIMA models based on the cut-off points of ACF &amp; PACF</a></span><ul class="toc-item"><li><span><a href="#ACF-&amp;-PACF" data-toc-modified-id="ACF-&amp;-PACF-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>ACF &amp; PACF</a></span><ul class="toc-item"><li><span><a href="#Original-Series" data-toc-modified-id="Original-Series-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>Original Series</a></span></li><li><span><a href="#Differenced-Time-series-with-(d-=-1)" data-toc-modified-id="Differenced-Time-series-with-(d-=-1)-7.1.2"><span class="toc-item-num">7.1.2&nbsp;&nbsp;</span>Differenced Time series with (d = 1)</a></span></li></ul></li><li><span><a href="#ARIMA-Model" data-toc-modified-id="ARIMA-Model-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>ARIMA Model</a></span><ul class="toc-item"><li><span><a href="#ARIMA(1,1,1)" data-toc-modified-id="ARIMA(1,1,1)-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>ARIMA(1,1,1)</a></span></li><li><span><a href="#SARIMA-Model" data-toc-modified-id="SARIMA-Model-7.2.2"><span class="toc-item-num">7.2.2&nbsp;&nbsp;</span>SARIMA Model</a></span><ul class="toc-item"><li><span><a href="#ACF-and-PACF-(differenced-d-=-1)" data-toc-modified-id="ACF-and-PACF-(differenced-d-=-1)-7.2.2.1"><span class="toc-item-num">7.2.2.1&nbsp;&nbsp;</span>ACF and PACF (differenced d = 1)</a></span></li><li><span><a href="#ACF-and-PACF-Seasonal-differece(12)" data-toc-modified-id="ACF-and-PACF-Seasonal-differece(12)-7.2.2.2"><span class="toc-item-num">7.2.2.2&nbsp;&nbsp;</span>ACF and PACF Seasonal differece(12)</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Table-with-All-Models" data-toc-modified-id="Table-with-All-Models-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Table with All Models</a></span></li><li><span><a href="#Run-the-best-model-(Manual-SARIMA)-on-full-dataset-and-predict-12-months-into-the-future-with-appropriate-confidence-intervals/bands" data-toc-modified-id="Run-the-best-model-(Manual-SARIMA)-on-full-dataset-and-predict-12-months-into-the-future-with-appropriate-confidence-intervals/bands-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Run the best model (Manual SARIMA) on full dataset and predict 12 months into the future with appropriate confidence intervals/bands</a></span><ul class="toc-item"><li><span><a href="#Run-best-model-with-fulldata" data-toc-modified-id="Run-best-model-with-fulldata-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Run best model with fulldata</a></span></li><li><span><a href="#Forcast-for-next-12-months-with-confidence-intervals" data-toc-modified-id="Forcast-for-next-12-months-with-confidence-intervals-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Forcast for next 12 months with confidence intervals</a></span></li></ul></li><li><span><a href="#Comment-on-the-model-thus-built-and-report-your-findings-and-suggest-the-measures-that-the-company-should-be-taking-for-future-sales" data-toc-modified-id="Comment-on-the-model-thus-built-and-report-your-findings-and-suggest-the-measures-that-the-company-should-be-taking-for-future-sales-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Comment on the model thus built and report your findings and suggest the measures that the company should be taking for future sales</a></span><ul class="toc-item"><li><span><a href="#Key-Findings:" data-toc-modified-id="Key-Findings:-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Key Findings:</a></span></li><li><span><a href="#Business-Recommendations:" data-toc-modified-id="Business-Recommendations:-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>Business Recommendations:</a></span></li></ul></li></ul></div>

# %% [markdown]
# # LOAD THE DATASETS
#
# (Read the data as an appropriate Time Series data and plot the data)

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn import metrics


import statsmodels.api as sm
import statsmodels.tsa.api as smt
import statsmodels.formula.api as smf
from   sklearn.metrics   import mean_squared_error
from   math              import sqrt

import warnings
warnings.filterwarnings("ignore")

# %%
import  matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['axes.labelsize'] = 12
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %% [markdown]
# ## Read the time-series datasets and plot the graph

# %%
# load the dataset for "Sparkling"
df= pd.read_csv('Sparkling.csv',parse_dates=True,index_col=0)
df.head(2)
# Out:
#             Sparkling
# YearMonth
# 1980-01-01       1686
# 1980-02-01       1591

# %%
plt.rcParams["figure.figsize"] = (18,3)
# Plotting the time series for "Sparkling"
df.plot(color='black')
plt.title('Sparkling Wine: Time Series Plot')
plt.xlabel('Year')
plt.ylabel('Wine Sales: Sparkling')
plt.grid();

# %% [markdown]
# __Insights:__
#
# __Sparkling:__ By looking at the graph, It looks like:
#
# - There is __no null values__ in the data. We will double check the same during EDA.
# - There is __seasonality__ in the data.

# %% [markdown]
# # Exploratory Data Analysis & Decomposition
#
# Perform appropriate Exploratory Data Analysis to understand the data and also perform decomposition.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Missing data check

# %%
#null value check
df.isnull().sum()
# Out:
# Sparkling    0
# dtype: int64

# %% [markdown]
# __Insights:__
#
# There is __no null values__ in the dataset

# %% [markdown]
# ### Basic measure of Descriptive Statistics

# %%
#descriptive summary
df.describe().T
# Out:
#            count         mean         std     min     25%     50%     75%  \
# Sparkling  187.0  2402.417112  1295.11154  1070.0  1605.0  1874.0  2549.0
#
#               max
# Sparkling  7242.0

# %%
#check skew of the dataset
df.skew()
# Out:
# Sparkling    1.817612
# dtype: float64

# %%
# Rolling mean and std dev plot

#calculate rolling mean and std dev with 3 months
rollmean = df['Sparkling'].rolling(3).mean()
rollstd = df['Sparkling'].rolling(3).std()

#plot the graph
original = plt.plot(df['Sparkling'], label='Original')
mean = plt.plot(rollmean, label='Rolling mean(3)')
std = plt.plot(rollstd, label='Rolling std(3)',color='black')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
# Out:
# Text(0.5, 1.0, 'Rolling Mean & Standard Deviation')

# %% [markdown]
# __Insights:__
#
# - In the dataset, we could see __huge variation/std across the years__.
# - In this dataset, __mean__ value is __higher__ then the __median__ value. It means, data is skewed.

# %% [markdown]
# ### Plot a year on year boxplot

# %%
#Yearwise Sparkling wine Sales Box plot
fig, ax = plt.subplots(figsize=(18,5))
sns.boxplot(x = df.index.year, y = df.Sparkling,data= df, ax=ax,whis=1.5)
plt.title('Sparkling Wine: Yearwise Box Plot')
plt.xlabel('Years');
plt.ylabel('Yearly Wine Sales: Sparkling');
plt.grid();

# %% [markdown]
# __Insights:__
#
# In yearwise boxplot, one key inference which is coming out as __median sales value of each year is almost same__. Further, __Year 1987 and 1988 are the highest sales years__ amongst other years.

# %% [markdown]
# ### Plot a monthly boxplot by taking all the years into account

# %%
#Monthwise Sparkling wine Sales Box plot
fig, ax = plt.subplots(figsize=(18,4))
sns.boxplot(x = df.index.month_name(), y = df.Sparkling,data= df, ax=ax,whis=1.5)
plt.title('Sparkling Wine: Monthwise Box Plot')
plt.xlabel('Month');
plt.ylabel('Monthwise Wine Sales: Sparkling');
plt.grid();

# %% [markdown]
# ### Plot a monthplot of the given time series

# %%
from statsmodels.graphics.tsaplots import month_plot

#Monthplot Sparkling wine Sales
fig, ax = plt.subplots(figsize=(18,4))
month_plot(df, ax=ax)
plt.title('Sparkling Wine: Month Plot')
plt.xlabel('Month');
plt.ylabel('Monthplot Wine Sales: Sparkling');
plt.grid();

# %% [markdown]
# ### Plot the Time Series according to different months for different years

# %%
yearly_across_months = pd.pivot_table(df, values = 'Sparkling', columns = df.index.month, 
                                        index = df.index.year)

yearly_across_months
# Out:
# YearMonth      1       2       3       4       5       6       7       8   \
# YearMonth
# 1980       1686.0  1591.0  2304.0  1712.0  1471.0  1377.0  1966.0  2453.0
# 1981       1530.0  1523.0  1633.0  1976.0  1170.0  1480.0  1781.0  2472.0
# 1982       1510.0  1329.0  1518.0  1790.0  1537.0  1449.0  1954.0  1897.0
# 1983       1609.0  1638.0  2030.0  1375.0  1320.0  1245.0  1600.0  2298.0
# 1984       1609.0  1435.0  2061.0  1789.0  1567.0  1404.0  1597.0  3159.0
# 1985       1771.0  1682.0  1846.0  1589.0  1896.0  1379.0  1645.0  2512.0
# 1986       1606.0  1523.0  1577.0  1605.0  1765.0  1403.0  2584.0  3318.0
# 1987       1389.0  1442.0  1548.0  1935.0  1518.0  1250.0  1847.0  1930.0
# 1988       1853.0  1779.0  2108.0  2336.0  1728.0  1661.0  2230.0  1645.0
# 1989       1757.0  1394.0  1982.0  1650.0  1654.0  1406.0  1971.0  1968.0
# 1990       1720.0  1321.0  1859.0  1628.0  1615.0  1457.0  1899.0  1605.0
# ...

# %%
#Sparkling Wine: Yearwise across months
fig, ax = plt.subplots(figsize=(16,4))
yearly_across_months.plot(ax=ax)
plt.title('Sparkling Wine: Yearwise across months')
plt.xlabel('Year');
plt.ylabel('Monthwise Wine Sales: Sparkling');
plt.grid();

# %% [markdown]
# __Insights:__
#
# __Sparkling:__ In monthwise boxplot, one key inference which is coming out is __first half of the year sales are on a lesser side__ but in the __second half the year sales are picking up__ mainly __last quarter of the year has highest sales amongst others__.
#
# Further, __November and December has the highest sales__ amongst other months.

# %% [markdown]
# ### Lag plot

# %%
#lag plot
from pandas.plotting import lag_plot
lag_plot(df)
plt.show();

# %% [markdown]
# __Insights:__
#
# - If the points cluster along a diagonal line from the bottom-left to the top-right of the plot, it suggests a positive correlation relationship.
# - If the points cluster along a diagonal line from the top-left to the bottom-right, it suggests a negative correlation relationship.
# - Either relationship is good as they can be modeled.
#
# More points tighter in to the diagonal line suggests a stronger relationship and more spread from the line suggests a weaker relationship. A ball in the middle or a spread across the plot suggests a weak or no relationship.
#
# In this dataset, we could see __weak relationship__ between the months is coming out because of spreaded points.

# %% [markdown]
# ## Decompose the Time Series

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 15,8

# %%
import  statsmodels.api          as       sm
from statsmodels.tsa.seasonal import seasonal_decompose

# %% [markdown]
# ### Additive Decomposition

# %%
## Additive Decomposition: Sparkling
decomposition_a = sm.tsa.seasonal_decompose(df,model='additive')
decomposition_a.plot();

# %% [markdown]
# __Insights:__
#
# In this additive decomposition, we could see that:
#
# - Trend value is moving from 2400 to 2200 to 2800 and back to 2400. so eventually no promising trend coming out.
# - Seasonality, out of mean of 2400, around 2200 is the seasonality which means, this dataset has the high seasonality.
# - Residuals, the range of the residual is also around +/- 1000 (which leads to noise).

# %%
## Getting the individual components from the Additive Decomposition: Sparkling
trend_a = decomposition_a.trend
seasonality_a = decomposition_a.seasonal
residual_a = decomposition_a.resid

print('Trend: Sparkling','\n',trend_a.head(12),'\n')
print('Seasonality: Sparkling','\n',seasonality_a.head(12),'\n')
print('Residual: Sparkling','\n',residual_a.head(12),'\n')
# Out:
# Trend: Sparkling
#  YearMonth
# 1980-01-01            NaN
# 1980-02-01            NaN
# 1980-03-01            NaN
# 1980-04-01            NaN
# 1980-05-01            NaN
# 1980-06-01            NaN
# 1980-07-01    2360.666667
# 1980-08-01    2351.333333
# 1980-09-01    2320.541667
# 1980-10-01    2303.583333
# 1980-11-01    2302.041667
# 1980-12-01    2293.791667
# Name: trend, dtype: float64
#
# Seasonality: Sparkling
#  YearMonth
# 1980-01-01    -854.260599
# 1980-02-01    -830.350678
# 1980-03-01    -592.356630
# 1980-04-01    -658.490559
# 1980-05-01    -824.416154
# 1980-06-01    -967.434011
# 1980-07-01    -465.502265
# 1980-08-01    -214.332821
# 1980-09-01    -254.677265
# 1980-10-01     599.769957
# 1980-11-01    1675.067179
# 1980-12-01    3386.983846
# Name: seasonal, dtype: float64
#
# Residual: Sparkling
#  YearMonth
# 1980-01-01           NaN
# 1980-02-01           NaN
# 1980-03-01           NaN
# 1980-04-01           NaN
# 1980-05-01           NaN
# ...

# %%
#Plot with original dataset with only trend component: Sparkling
df.plot(figsize=(16,4))
trend_a.plot(figsize=(16,4))
plt.legend(["Original Time Series for Sparkling", "Only Trend Component for Sparkling"]);

# %% [markdown]
# ### Multiplicative Decomposition

# %%
## Multiplicative Decomposition: Sparkling
decomposition_m = sm.tsa.seasonal_decompose(df,model='multiplicative')
decomposition_m.plot();

# %% [markdown]
# __Insights:__
#
# In this multiplicative decomposition, we could see that:
#
# - Trend value is moving from 2400 to 2200 to 2800 and back to 2400. so eventually no promising trend coming out.
# - Seasonality, is at high which is almost 100%.
# - Residuals, are almost +/- 50%. (which leads to noise).

# %%
## Getting the individual components from the Multiplicative Decomposition: Sparkling
trend_m = decomposition_m.trend
seasonality_m = decomposition_m.seasonal
residual_m = decomposition_m.resid

print('Trend: Sparkling','\n',trend_m.head(12),'\n')
print('Seasonality: Sparkling','\n',seasonality_m.head(12),'\n')
print('Residual: Sparkling','\n',residual_m.head(12),'\n')
# Out:
# Trend: Sparkling
#  YearMonth
# 1980-01-01            NaN
# 1980-02-01            NaN
# 1980-03-01            NaN
# 1980-04-01            NaN
# 1980-05-01            NaN
# 1980-06-01            NaN
# 1980-07-01    2360.666667
# 1980-08-01    2351.333333
# 1980-09-01    2320.541667
# 1980-10-01    2303.583333
# 1980-11-01    2302.041667
# 1980-12-01    2293.791667
# Name: trend, dtype: float64
#
# Seasonality: Sparkling
#  YearMonth
# 1980-01-01    0.649843
# 1980-02-01    0.659214
# 1980-03-01    0.757440
# 1980-04-01    0.730351
# 1980-05-01    0.660609
# 1980-06-01    0.603468
# 1980-07-01    0.809164
# 1980-08-01    0.918822
# 1980-09-01    0.894367
# 1980-10-01    1.241789
# 1980-11-01    1.690158
# 1980-12-01    2.384776
# Name: seasonal, dtype: float64
#
# Residual: Sparkling
#  YearMonth
# 1980-01-01         NaN
# 1980-02-01         NaN
# 1980-03-01         NaN
# 1980-04-01         NaN
# 1980-05-01         NaN
# 1980-06-01         NaN
# 1980-07-01    1.029230
# ...

# %%
#Plot with original dataset with only trend component: Sparkling
df.plot(figsize=(16,4))
trend_m.plot(figsize=(16,4))
plt.legend(["Original Time Series for Sparkling", "Only Trend Component for Sparkling"]);

# %% [markdown]
# # Train - Test Split

# %%
# train and test split
train    =   df[df.index<'1991']
test     =   df[df.index>='1991']

# %%
# shape of the dataset with head and tail of the dataset.
print("Train Dataset: Sparkling")
print(train.head(2))
print(train.tail(2))
print('\n')
print("Train Dataset Shape:", train.shape)
print('\n')
print("Test Dataset: Sparkling")
print(test.head(2))
print(test.tail(2))
print('\n')
print("Test Dataset Shape:", test.shape)
# Out:
# Train Dataset: Sparkling
#             Sparkling
# YearMonth
# 1980-01-01       1686
# 1980-02-01       1591
#             Sparkling
# YearMonth
# 1990-11-01       4286
# 1990-12-01       6047
#
#
# Train Dataset Shape: (132, 1)
#
#
# Test Dataset: Sparkling
#             Sparkling
# YearMonth
# 1991-01-01       1902
# 1991-02-01       2049
#             Sparkling
# YearMonth
# 1995-06-01       1688
# 1995-07-01       2031
#
#
# Test Dataset Shape: (55, 1)

# %%
### Plot data
train['Sparkling'].plot(figsize=(16,4), title= 'Sparkling Wine: Train & Test Split', fontsize=14)
test['Sparkling'].plot(figsize=(16,4), title= 'Sparkling Wine: Train & Test Split', fontsize=14)
# Out:
# <AxesSubplot:title={'center':'Sparkling Wine: Train & Test Split'}, xlabel='YearMonth'>

# %% [markdown]
# # Model Building using various Time series techniques

# %% [markdown]
# ## Model 1: Regression on Time

# %%
#Creating copy of train and test for this model
train_reg   = train.copy()
test_reg    = test.copy()

# %%
# creating time variable for train data which would be useful for this model
time       = [i+1 for i in range(len(train_reg))]
train_reg['time'] = time
train_reg.head(2)
# Out:
#             Sparkling  time
# YearMonth
# 1980-01-01       1686     1
# 1980-02-01       1591     2

# %%
# creating time variable for test data which would be useful for this model
time       = [i+1 for i in range(len(test_reg))]
test_reg['time'] = time
test_reg.head(2)
# Out:
#             Sparkling  time
# YearMonth
# 1991-01-01       1902     1
# 1991-02-01       2049     2

# %%
#Train test split based on times eries variable
x_train_reg = train_reg.drop('Sparkling', axis=1)
x_test_reg  = test_reg.drop('Sparkling', axis=1)
y_train_reg = train_reg[['Sparkling']]
y_test_reg  = test_reg[['Sparkling']]

# %%
# fit the linear regression model
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train_reg, y_train_reg)
# Out:
# LinearRegression()

# %%
#predictions on test data
predictions         = model.predict(x_test_reg)
y_test_reg['RegOnTime'] = predictions

#graphical view on train, test data including regression on time (line)
plt.figure(figsize=(12,4))
plt.plot(train_reg['Sparkling'], label='Train_Reg: Sparkling')
plt.plot(test_reg['Sparkling'], label='Test_Reg: Sparkling')
plt.plot(y_test_reg['RegOnTime'], label='Regression On Time: Sparkling')
plt.legend(loc='best')

# %%
rmse_reg = sqrt(mean_squared_error(test_reg.Sparkling, y_test_reg.RegOnTime))
rmse_reg = round(rmse_reg, 3)
print("For RegressionOnTime: Sparkling,  RMSE is %3.3f" %(rmse_reg))
# Out:
# For RegressionOnTime: Sparkling,  RMSE is 1294.440

# %%
#store the RMSE details in the table
resultsDf= pd.DataFrame({'Model':['RegressionOnTime'], 'WineType':['Sparkling'], 'Test_RMSE': [rmse_reg]})

# %% [markdown]
# ## Model 2: Regression on Time With Seasonal Components

# %%
#Creating copy of train and test for this model
train_ROTS   = train.copy()
test_ROTS    = test.copy()

# %%
# define time and monthseasonality for train data
time = [i+1 for i in range(len(train_ROTS))]
train_ROTS['time'] = time
monthSeasonality = ['m1', 'm2', 'm3', 'm4', 'm5', 'm6', 'm7', 'm8', 'm9', 'm10', 'm11', 'm12'] #defining the 12 months

# define time and monthseasonality for test data
# excluding year which doesn't have full year seasonality incldued 
#(i.e. 1995 have only 7 months hence exluding the same from test dataset)
time = [i+1 for i in range(len(test_ROTS)-7)]
test_ROTS = test_ROTS[test_ROTS.index <= '1994-12-01']
test_ROTS['time'] = time
monthSeasonality = ['m1', 'm2', 'm3', 'm4', 'm5', 'm6', 'm7', 'm8', 'm9', 'm10', 'm11', 'm12'] #defining the 12 months

# %%
train_ROTS['monthSeasonality'] = monthSeasonality * 11  # it is multiplied by 11 as there are 132 observations
train_ROTS.head(13)
# Out:
#             Sparkling  time monthSeasonality
# YearMonth
# 1980-01-01       1686     1               m1
# 1980-02-01       1591     2               m2
# 1980-03-01       2304     3               m3
# 1980-04-01       1712     4               m4
# 1980-05-01       1471     5               m5
# 1980-06-01       1377     6               m6
# 1980-07-01       1966     7               m7
# 1980-08-01       2453     8               m8
# 1980-09-01       1984     9               m9
# 1980-10-01       2596    10              m10
# 1980-11-01       4087    11              m11
# 1980-12-01       5179    12              m12
# 1981-01-01       1530    13               m1

# %%
test_ROTS['monthSeasonality'] = monthSeasonality * 4  # it is multiplied by 4 as there are 48 observations
test_ROTS.head(2)
# Out:
#             Sparkling  time monthSeasonality
# YearMonth
# 1991-01-01       1902     1               m1
# 1991-02-01       2049     2               m2

# %%
train_ROTSComplete = pd.get_dummies(train_ROTS, drop_first=True)
train_ROTSComplete.head(2).T
# Out:
# YearMonth             1980-01-01  1980-02-01
# Sparkling                   1686        1591
# time                           1           2
# monthSeasonality_m10           0           0
# monthSeasonality_m11           0           0
# monthSeasonality_m12           0           0
# monthSeasonality_m2            0           1
# monthSeasonality_m3            0           0
# monthSeasonality_m4            0           0
# monthSeasonality_m5            0           0
# monthSeasonality_m6            0           0
# monthSeasonality_m7            0           0
# monthSeasonality_m8            0           0
# monthSeasonality_m9            0           0

# %%
test_ROTSComplete = pd.get_dummies(test_ROTS, drop_first=True)
test_ROTSComplete.head(2).T
# Out:
# YearMonth             1991-01-01  1991-02-01
# Sparkling                   1902        2049
# time                           1           2
# monthSeasonality_m10           0           0
# monthSeasonality_m11           0           0
# monthSeasonality_m12           0           0
# monthSeasonality_m2            0           1
# monthSeasonality_m3            0           0
# monthSeasonality_m4            0           0
# monthSeasonality_m5            0           0
# monthSeasonality_m6            0           0
# monthSeasonality_m7            0           0
# monthSeasonality_m8            0           0
# monthSeasonality_m9            0           0

# %%
#x,y  train test split
x_train_ROTS  = train_ROTSComplete.drop('Sparkling', axis=1)
x_test_ROTS   = test_ROTSComplete.drop('Sparkling', axis=1)
y_train_ROTS  = train_ROTSComplete[['Sparkling']]
y_test_ROTS   = test_ROTSComplete[['Sparkling']]

# %%
# fit the model
model    = LinearRegression()
model.fit(x_train_ROTS, y_train_ROTS)
# Out:
# LinearRegression()

# %%
#prediction on the test data
predictions = model.predict(x_test_ROTS)
y_test_ROTS['RegOnTimeSeasonal'] = predictions

#plot the graph
plt.figure(figsize=(12,4))
plt.plot(train_ROTSComplete['Sparkling'], label='Train_RegonTimeSeasonal')
plt.plot(test_ROTSComplete['Sparkling'], label='Test_RegonTimeSeasonal')
plt.plot(y_test_ROTS['RegOnTimeSeasonal'], label='Regression On Time With Seasonal Components',color='black')
plt.legend(loc='best')

# %%
#RMSE calculation on test data
rmse_ROTS = sqrt(mean_squared_error(test_ROTSComplete.Sparkling, y_test_ROTS.RegOnTimeSeasonal))
rmse_ROTS = round(rmse_ROTS,3)
print("For RegOnTimeSeasonal,  RMSE is %3.3f" %(rmse_ROTS))
# Out:
# For RegOnTimeSeasonal,  RMSE is 427.472

# %%
#store the RMSE details in the table
tempResultsDf= pd.DataFrame({'Model':['RegressionOnTimeSeasonal'], 'WineType':['Sparkling'],
                              'Test_RMSE': [rmse_ROTS]})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# ## Model 3: Naive Approach:  𝑦̂ 𝑡+1=𝑦𝑡

# %%
# copy the train dataset as array and create copy of test dataset.
dd_s = np.asarray(train.Sparkling)
y_hat_s = test.copy()
y_hat_s['naive'] = dd_s[len(dd_s)-1]

# %%
# plot the graph
plt.figure(figsize=(12,4))
plt.plot(train.index, train['Sparkling'], label='Train_Naive')
plt.plot(test.index,test['Sparkling'], label='Test_Naive')
plt.plot(y_hat_s.index,y_hat_s['naive'], label='Naive Forecast')
plt.legend(loc='best')
plt.title("Naive Forecast: Sparkling")
# Out:
# Text(0.5, 1.0, 'Naive Forecast: Sparkling')

# %%
# RMSE calculation on test data
rmse_Naive = sqrt(mean_squared_error(test.Sparkling, y_hat_s.naive))
rmse_Naive = round(rmse_Naive, 3)
print("For Naive model,  RMSE is %3.3f" %(rmse_Naive))
# Out:
# For Naive model,  RMSE is 3864.279

# %%
#store the RMSE details in the table
tempResultsDf= pd.DataFrame({'Model':['Naive model'], 'WineType':['Sparkling'],
                              'Test_RMSE': [rmse_Naive]})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# We can infer from the RMSE. Furrther above table shows that:
#
# - __Naive method and Regression on Time model are not suited__.
#
# - __Regression on Time Seasonal__ is the __best suit__. But we can still _improve our score by adopting different techniques_.
#
# Now we will look at __another techniques and try to improve our score__.

# %% [markdown]
# ## Model 4: Simple Average

# %%
# create the copy of the test dataset
y_hat_avg_s = test.copy()

#create varible with putting train data mean
y_hat_avg_s['avg_forecast'] = train['Sparkling'].mean()

#plot the graph
plt.figure(figsize=(12,4))
plt.plot(train['Sparkling'], label='trainimpleAvg')
plt.plot(test['Sparkling'], label='testimpleAvg')
plt.plot(y_hat_avg_s['avg_forecast'], label='Average Forecast')
plt.legend(loc='best')

# %%
#RMSE calculation on test data
rmse_SA = sqrt(mean_squared_error(test.Sparkling, y_hat_avg_s.avg_forecast))
rmse_SA = round(rmse_SA, 3)
print("For Simple Average model,  RMSE is %3.3f" %(rmse_SA))
# Out:
# For Simple Average model,  RMSE is 1275.082

# %%
#store the RMSE details in the table
tempResultsDf= pd.DataFrame({'Model':['Simple Average'], 'WineType':['Sparkling'],
                              'Test_RMSE': [rmse_SA]})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# ## Model 5: Moving Average(MA)

# %%
# create the copy for full dataset
df_MA = df.copy()

# %%
# rolling MA details
df_MA['moving_avg_forecast_3']  = df_MA['Sparkling'].rolling(3).mean()
df_MA['moving_avg_forecast_4']  = df_MA['Sparkling'].rolling(4).mean()
df_MA['moving_avg_forecast_5']  = df_MA['Sparkling'].rolling(5).mean()
df_MA['moving_avg_forecast_6']  = df_MA['Sparkling'].rolling(6).mean()
df_MA['moving_avg_forecast_8']  = df_MA['Sparkling'].rolling(8).mean()
df_MA['moving_avg_forecast_12'] = df_MA['Sparkling'].rolling(12).mean()

# %%
# define the column with MA rolling months
cols = ['moving_avg_forecast_3','moving_avg_forecast_4', 
        'moving_avg_forecast_5','moving_avg_forecast_6','moving_avg_forecast_8','moving_avg_forecast_12']

# %%
#Creating train and test set 
train_MA = df_MA[df_MA.index<'1991'] 
test_MA  = df_MA[df_MA.index>='1991']

# %%
# create for loop to build moving average for defined columns
y_hat_avg_MA = test_MA.copy()

for col_name in cols:
    
    plt.figure(figsize=(12,4))
    plt.plot(train_MA['Sparkling'], label='Train_MA')
    plt.plot(test_MA['Sparkling'], label='Test_MA')
    plt.plot(y_hat_avg_MA[col_name], label = col_name, color = 'black')
    plt.legend(loc = 'best')
    
    rmse_MA = sqrt(mean_squared_error(test_MA.Sparkling, y_hat_avg_MA[col_name]))
    rmse_MA = round(rmse_MA, 3)
    print("For Moving Average model, %s  RMSE is %3.3f" %(col_name, rmse_MA))
    
    #Defining the data frame with the model evaluation parameters
    tempResultsDf= pd.DataFrame({'Model':[col_name], 'WineType':['Sparkling'], 'Test_RMSE': [rmse_MA]})
    resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')
# Out:
# For Moving Average model, moving_avg_forecast_3  RMSE is 1028.606
# For Moving Average model, moving_avg_forecast_4  RMSE is 1156.590
# For Moving Average model, moving_avg_forecast_5  RMSE is 1234.045
# For Moving Average model, moving_avg_forecast_6  RMSE is 1283.927
# For Moving Average model, moving_avg_forecast_8  RMSE is 1342.568
# For Moving Average model, moving_avg_forecast_12  RMSE is 1267.925

# %% [markdown]
# ## Model 6: Simple Exponential Smoothing (SES)

# %%
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt

# %%
# create class
model_SES = SimpleExpSmoothing(train['Sparkling'])

# %%
#fit the model
model_SES_fit = model_SES.fit(optimized = True)

# %%
print('')
print('== Simple Exponential Smoothing (SES) ')
print('')

print('')
print('Smoothing Level', np.round(model_SES_fit.params['smoothing_level'], 4))
print('Initial Level',   np.round(model_SES_fit.params['initial_level'], 4))
print('')
# Out:
# == Simple Exponential Smoothing (SES)
#
#
# Smoothing Level 0.0496
# Initial Level 1818.5048

# %%
y_hat_avg_SES = test.copy()
y_hat_avg_SES['SES']     = model_SES_fit.forecast(len(test['Sparkling']))

alpha_value          = np.round(model_SES_fit.params['smoothing_level'], 4)


plt.figure(figsize=(12,4))
plt.plot(train.index, train['Sparkling'], label = 'Train_SES')
plt.plot(test.index, test['Sparkling'],   label = 'Test_SES')
plt.plot(test.index, y_hat_avg_SES.SES,   label = 'SES_OPT')
plt.title('SES with alpha ' + str(alpha_value))
plt.legend(loc='best') 
plt.show()

# %% [markdown]
# The alpha value is  close to 0 indicates slow learning (past observations have a large influence on forecasts).

# %%
rmse_SES = sqrt(mean_squared_error(test['Sparkling'], y_hat_avg_SES.SES))
rmse_SES = round(rmse_SES, 3)
print("For SES model: For alpha = %1.2f,  RMSE is %3.3f" %(alpha_value,rmse_SES))
# Out:
# For SES model: For alpha = 0.05,  RMSE is 1316.035

# %%
tempResultsDf= pd.DataFrame({'Model': 'SES(L:0.05)', 'WineType':['Sparkling'],
                              'Test_RMSE': [rmse_SES]})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# ## Model 7: SES model - Best alpha with least RMSE

# %%
resultsDf_model = pd.DataFrame({'Alpha Values':[],'Test RMSE': []})
resultsDf_model

y_hat_leastRMSE_SES = test.copy()

for i in np.arange(0.01,1,0.01):
    model_SES_alpha_i = model_SES.fit(smoothing_level=i,optimized=False,use_brute=True)
    y_hat_leastRMSE_SES['predict',i] = model_SES_alpha_i.forecast(steps=len(test))
    
    rmse_model7_test_i = metrics.mean_squared_error(test['Sparkling'],y_hat_leastRMSE_SES['predict',i],squared=False)
        
    resultsDf_model = resultsDf_model.append({'Alpha Values':i
                                              ,'Test RMSE':rmse_model7_test_i}, ignore_index=True)

# %%
SES_least_rmse = resultsDf_model.sort_values(by=['Test RMSE'],ascending=True)
SES_least_rmse.head(2)
# Out:
#    Alpha Values    Test RMSE
# 1          0.02  1279.495201
# 0          0.01  1281.032699

# %%
print("For SES model(least RMSE): For alpha = %3.2f,  RMSE is %3.3f"
    %(SES_least_rmse.iloc[0].values[0],SES_least_rmse.iloc[0].values[1]))
# Out:
# For SES model(least RMSE): For alpha = 0.02,  RMSE is 1279.495

# %%
plt.figure(figsize=(12,4))
plt.plot(train.index, train['Sparkling'], label = 'Train_SES')
plt.plot(test.index, test['Sparkling'],   label = 'Test_SES')
#at this location we have alpha value with predict0.02
plt.plot(test.index, y_hat_leastRMSE_SES.iloc[:,1],   label = 'SES_LEAST_RMSE') 
plt.title('SES LEAST RMSE with alpha 0.02')
plt.legend(loc='best') 
plt.show()

# %% [markdown]
# The alpha value is still close to 0 indicates slow learning (past observations have a large influence on forecasts).

# %%
tempResultsDf= pd.DataFrame({'Model': 'SES(least RMSE)(L:0.02)', 'WineType':['Sparkling'],
                              'Test_RMSE': [SES_least_rmse.iloc[0].values[1]]})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# ## Model 8: Holt's Linear Trend Method (Double Exponential Smoothing)

# %%
import statsmodels.api as sm

# %%
y_hat_avg_DES = test.copy()

model_DES = Holt(train['Sparkling'])

model_DES_fit = Holt(np.asarray(train['Sparkling'])).fit(optimized=True)

y_hat_avg_DES['Holt_linear'] = model_DES_fit.forecast(len(test))

# %%
print('')
print('==Holt model Exponential Smoothing Parameters ==')
print('')
alpha_DES_value = np.round(model_DES_fit.params['smoothing_level'], 4)
beta_DES_value  = np.round(model_DES_fit.params['smoothing_trend'], 4)

print('Smoothing Level', alpha_DES_value)
print('Smoothing Trend', beta_DES_value)
print('Initial Level',   np.round(model_DES_fit.params['initial_level'], 4))
print('')
# Out:
# ==Holt model Exponential Smoothing Parameters ==
#
# Smoothing Level 0.6886
# Smoothing Trend 0.0001
# Initial Level 1686.0

# %%
plt.figure(figsize=(12,4))
plt.plot(train['Sparkling'], label='Train_DES')
plt.plot(test['Sparkling'], label='Test_DES')
plt.plot(y_hat_avg_DES['Holt_linear'], label='Holt_linear')
plt.title('DES with alpha ' + str(alpha_DES_value) + ' and beta ' + str(beta_DES_value))
plt.legend(loc='best')
plt.show()

# %%
rmse_DES            =  np.sqrt(mean_squared_error(test['Sparkling'], y_hat_avg_DES['Holt_linear']))

print("For alpha = %1.2f, For beta = %1.2f,  RMSE is %4.2f" 
      %(alpha_DES_value, beta_DES_value, rmse_DES))
# Out:
# For alpha = 0.69, For beta = 0.00,  RMSE is 2007.24

# %%
tempResultsDf= pd.DataFrame({'Model': 'DES(Holt_linear)(L:0.69,T:0.0)', 'WineType':['Sparkling'],
                              'Test_RMSE': rmse_DES})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# ## Model 9: DES model - Best alpha and beta with least RMSE

# %%
## First we will define an empty dataframe to store our values from the loop

resultsDfDES_model = pd.DataFrame({'Alpha Values':[],'Beta Values':[],'Test RMSE': []})
resultsDfDES_model

y_hat_leastRMSE_DES = test.copy()

modelDES = Holt(train['Sparkling'])

for i in np.arange(0.01,1,0.01):
    for j in np.arange(0.01,1,0.01):
        modelDES_alpha_i_j = modelDES.fit(smoothing_level=i,smoothing_trend=j,optimized=False)
        y_hat_leastRMSE_DES['predict',i,j] = modelDES_alpha_i_j.forecast(steps=len(test))
                
        rmse_model9DES_test = metrics.mean_squared_error(test['Sparkling'],y_hat_leastRMSE_DES['predict',i,j],squared=False)
        
        resultsDfDES_model = resultsDfDES_model.append({'Alpha Values':i,'Beta Values':j
                                          ,'Test RMSE':rmse_model9DES_test}, ignore_index=True)

# %%
DES_least_rmse = resultsDfDES_model.sort_values(by=['Test RMSE'],ascending=True)
DES_least_rmse.head(2)
# Out:
#      Alpha Values  Beta Values    Test RMSE
# 148          0.02         0.50  1274.630824
# 115          0.02         0.17  1275.105310

# %%
plt.figure(figsize=(12,4))
plt.plot(train.index, train['Sparkling'], label = 'Train_DES')
plt.plot(test.index, test['Sparkling'],   label = 'Test_DES')

plt.plot(test.index, y_hat_leastRMSE_DES['predict',0.02,0.50],   label = 'DES_LEAST_RMSE') 
plt.title('DES LEAST RMSE with alpha 0.02 and beta 0.50')
plt.legend(loc='best') 
plt.show()

# %%
print("For DES model(least RMSE): For alpha = %1.2f, beta = %1.2f, RMSE is %3.2f"
    %(DES_least_rmse.iloc[0].values[0],DES_least_rmse.iloc[0].values[1],DES_least_rmse.iloc[0].values[2]))
# Out:
# For DES model(least RMSE): For alpha = 0.02, beta = 0.50, RMSE is 1274.63

# %%
tempResultsDf= pd.DataFrame({'Model': 'DES(least RMSE)(L:0.02,T:0.50)', 'WineType':['Sparkling'],
                              'Test_RMSE': [DES_least_rmse.iloc[0].values[2]]})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# ## Model 10: Holt-Winters Method - Additive seasonality

# %%
y_hat_TES_a_avg = test.copy()

# %%
model_TES_a_fit = ExponentialSmoothing(np.asarray(train['Sparkling']),
                                         seasonal_periods = 12 ,trend='add', seasonal='add').fit()

# %%
y_hat_TES_a_avg['Holt_Winter'] = model_TES_a_fit.forecast(len(test))

# %%
print('')
print('== Holt-Winters Additive ETS(A,A,A) Parameters ==')
print('')
alpha_TES_a_value = np.round(model_TES_a_fit.params['smoothing_level'], 4)
beta_TES_a_value  = np.round(model_TES_a_fit.params['smoothing_trend'], 4)
gamma_TES_a_value = np.round(model_TES_a_fit.params['smoothing_seasonal'], 4) 

print('Smoothing Level: ', alpha_TES_a_value)
print('Smoothing Trend: ', beta_TES_a_value)
print('Smoothing Seasonal: ', gamma_TES_a_value)
print('Initial Level: ', np.round(model_TES_a_fit.params['initial_level'], 4))
print('Initial Trend: ', np.round(model_TES_a_fit.params['initial_trend'], 4))
print('Initial Seasons: ', np.round(model_TES_a_fit.params['initial_seasons'], 4))
print('')
# Out:
# == Holt-Winters Additive ETS(A,A,A) Parameters ==
#
# Smoothing Level:  0.1125
# Smoothing Trend:  0.0375
# Smoothing Seasonal:  0.4937
# Initial Level:  1640.1903
# Initial Trend:  -2.8837
# Initial Seasons:  [  45.9036  -48.989   662.9357   72.6896 -168.8846 -262.4524  326.0668
#   813.2342  344.3313  956.0857 2446.8137 3538.46  ]

# %%
plt.figure(figsize=(12,4))
plt.plot(train['Sparkling'], label='Train_TES')
plt.plot(test['Sparkling'], label='Test_TES')
plt.plot(y_hat_TES_a_avg['Holt_Winter'], label='Holt_Winter', color='black')
plt.title('Holt-Winters Additive ETS(A,A,A) Parameters:\n  alpha = ' + 
          str(alpha_TES_a_value) + '  Beta:' + 
          str(beta_TES_a_value) +
          '  Gamma: ' + str(gamma_TES_a_value))
plt.legend(loc='best')

# %%
rmse_TES_a             =  np.sqrt(mean_squared_error(test['Sparkling'], y_hat_TES_a_avg['Holt_Winter']))

print("For TES(Additive) model: alpha = %1.2f, beta = %1.2f, gamma = %1.2f, RMSE is %3.2f" 
      %(alpha_TES_a_value, beta_TES_a_value, gamma_TES_a_value, rmse_TES_a))
# Out:
# For TES(Additive) model: alpha = 0.11, beta = 0.04, gamma = 0.49, RMSE is 473.95

# %%
#store the RMSE details in the table
tempResultsDf= pd.DataFrame({'Model': 'TES(Holt_Winter)-Add(L:0.11,T:0.04,S:0.49)', 'WineType':['Sparkling'],
                              'Test_RMSE': rmse_TES_a})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# ## Model 11: Holt-Winters Method - Multiplicative seasonality

# %%
y_hat_TES_m_avg = test.copy()

# %%
model_TES_m_fit = ExponentialSmoothing(np.asarray(train['Sparkling']),
                                         seasonal_periods = 12 ,trend='add', seasonal='mul').fit()

# %%
y_hat_TES_m_avg['Holt_Winter'] = model_TES_m_fit.forecast(len(test))

# %%
print('')
print('== Holt-Winters Multiplicative ETS(A,A,M) Parameters ==')
print('')
alpha_TES_m_value = np.round(model_TES_m_fit.params['smoothing_level'], 4)
beta_TES_m_value  = np.round(model_TES_m_fit.params['smoothing_trend'], 4)
gamma_TES_m_value = np.round(model_TES_m_fit.params['smoothing_seasonal'], 4) 

print('Smoothing Level: ', alpha_TES_m_value)
print('Smoothing Trend: ', beta_TES_m_value)
print('Smoothing Seasonal: ', gamma_TES_m_value)
print('Initial Level: ', np.round(model_TES_m_fit.params['initial_level'], 4))
print('Initial Trend: ', np.round(model_TES_m_fit.params['initial_trend'], 4))
print('Initial Seasons: ', np.round(model_TES_m_fit.params['initial_seasons'], 4))
print('')
# Out:
# == Holt-Winters Multiplicative ETS(A,A,M) Parameters ==
#
# Smoothing Level:  0.1111
# Smoothing Trend:  0.0617
# Smoothing Seasonal:  0.3949
# Initial Level:  1639.5306
# Initial Trend:  -13.8037
# Initial Seasons:  [1.0441 1.001  1.4046 1.2091 0.9641 0.9675 1.3048 1.6984 1.3703 1.8166
#  2.8471 3.6246]

# %%
plt.figure(figsize=(12,4))
plt.plot(train['Sparkling'], label='Train_TES')
plt.plot(test['Sparkling'], label='Test_TES')
plt.plot(y_hat_TES_m_avg['Holt_Winter'], label='Holt_Winter', color='black')
plt.title('Holt-Winters Multiplicative ETS(A,A,M) Parameters:\n  alpha = ' + 
          str(alpha_TES_m_value) + '  Beta:' + 
          str(beta_TES_m_value) +
          '  Gamma: ' + str(gamma_TES_m_value))
plt.legend(loc='best')

# %%
rmse_TES_m             =  np.sqrt(mean_squared_error(test['Sparkling'], y_hat_TES_m_avg['Holt_Winter']))

print("For TES(Multiplicative) alpha = %1.2f, beta = %1.2f, gamma = %1.2f, RMSE is %3.2f" 
      %(alpha_TES_m_value, beta_TES_m_value, gamma_TES_m_value, rmse_TES_m))
# Out:
# For TES(Multiplicative) alpha = 0.11, beta = 0.06, gamma = 0.39, RMSE is 469.43

# %%
#store the RMSE details in the table
tempResultsDf= pd.DataFrame({'Model': 'TES(Holt_Winter)-Mul(L:0.11,T:0.06,S:0.39)', 'WineType':['Sparkling'],
                              'Test_RMSE': rmse_TES_m})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# __Let's Try some advanced models and get RMSE value corresponding to those models.__

# %% [markdown]
# # Check for stationarity on Time Series data (Full data & Train data).

# %% [markdown]
# What are characteristics of stationarity:
#
# - __Mean__ should be __constant__
#
# - __Variance__ should be __constant__
#
# - __Covariance__ for a time period should be __constant__

# %% [markdown]
# __Hypothesis to check Stationarity:__
#
#  __H0__ : Time series is __non-stationary__
#
#  __H1__ : Time series is __stationary__

# %% [markdown]
# __Note:__ If the series is non-stationary, stationarise the time series by taking a difference of the time series. Then we can use this particular differenced series to train the models. __We do not need to worry about stationarity for the Test Data__ because we are not building any models on the test Data, we are only evaluating our models over there.

# %% [markdown]
# __Auto-Correlation Plot:__

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df)
plt.show();

# %% [markdown]
# __Insights:__
#
# We can quantify the strength and type of relationship between observations and their lags. In statistics, this is called correlation, and when calculated against lag values in time series it is called autocorrelation (self-correlation).
#
# A correlation value calculated between two groups of numbers, such as observations and their lag1 values, results in a number between -1 and 1. The sign of this number indicates a negative or positive correlation respectively.
# A value close to zero suggests a weak correlation, whereas a value closer to -1 or 1 indicates a strong correlation.
# Dotted lines are provided that indicate any correlation values above those lines are statistically significant (meaningful).

# %% [markdown]
# ## ADF Test

# %%
from statsmodels.tsa.stattools import adfuller
from matplotlib.pyplot import figure

# %%
dftest = adfuller(df,regression='ct')
print('dftest statistic is %3.3f' %dftest[0])
print('dftest p-value is' ,dftest[1])
print('Number of lags used' ,dftest[2])
# Out:
# dftest statistic is -1.798
# dftest p-value is 0.7055958459932397
# Number of lags used 12

# %%
dftest = adfuller(train,regression='ct')
print('dftest statistic is %3.3f' %dftest[0])
print('dftest p-value is' ,dftest[1])
print('Number of lags used' ,dftest[2])
# Out:
# dftest statistic is -2.062
# dftest p-value is 0.5674110388593719
# Number of lags used 12

# %% [markdown]
# We see that __𝛼 (alpha) values__ of full dataset and train dataset are __more than 0.05__. Hence, the Time Series data for _Sparkling wine_ is __non-stationary__.

# %% [markdown]
# ## Convert Non-stationary to Stationary

# %% [markdown]
# __Let's take a difference of order 1 and check whether the Time Series is stationary or not.__

# %%
dftest = adfuller(df.diff(1).dropna(),regression='ct')
print('dftest statistic is %3.3f' %dftest[0])
print('dftest p-value is' ,dftest[1])
print('Number of lags used' ,dftest[2])
# Out:
# dftest statistic is -44.912
# dftest p-value is 0.0
# Number of lags used 10

# %%
(df.diff(1).dropna()).plot(grid=True,figsize=(16, 3));
plt.title('Sparkling Wine: Full data with difference order = 1')
# Out:
# Text(0.5, 1.0, 'Sparkling Wine: Full data with difference order = 1')

# %%
dftest = adfuller(train.diff(1).dropna(),regression='ct')
print('dftest statistic is %3.3f' %dftest[0])
print('dftest p-value is' ,dftest[1])
print('Number of lags used' ,dftest[2])
# Out:
# dftest statistic is -7.968
# dftest p-value is 8.479210655514579e-11
# Number of lags used 11

# %%
(train.diff(1).dropna()).plot(grid=True,figsize=(16, 3));
plt.title('Sparkling Wine: Train data with difference order = 1')
# Out:
# Text(0.5, 1.0, 'Sparkling Wine: Train data with difference order = 1')

# %% [markdown]
# __We see that after taking difference of order 1 the series have become stationary at alpha = 0.05.__

# %% [markdown]
# # Model 12 & 13: Automated version of ARIMA & SARIMA model with least AIC (Akaike Information Criteria) value

# %% [markdown]
# ## ARIMA Model

# %%
## The following loop helps us in getting a combination of different parameters of p and q in the range of 0 and 5
## We have kept the value of d as 1 as we need to take a difference of the series to make it stationary.

import itertools
p = q = range(0, 5)
d= range(1,2)
pdq = list(itertools.product(p, d, q))
print('Some parameter combinations for the Model...')
for i in range(1,len(pdq)):
    print('Model: {}'.format(pdq[i]))
# Out:
# Some parameter combinations for the Model...
# Model: (0, 1, 1)
# Model: (0, 1, 2)
# Model: (0, 1, 3)
# Model: (0, 1, 4)
# Model: (1, 1, 0)
# Model: (1, 1, 1)
# Model: (1, 1, 2)
# Model: (1, 1, 3)
# Model: (1, 1, 4)
# Model: (2, 1, 0)
# Model: (2, 1, 1)
# Model: (2, 1, 2)
# Model: (2, 1, 3)
# Model: (2, 1, 4)
# Model: (3, 1, 0)
# Model: (3, 1, 1)
# Model: (3, 1, 2)
# Model: (3, 1, 3)
# Model: (3, 1, 4)
# Model: (4, 1, 0)
# Model: (4, 1, 1)
# Model: (4, 1, 2)
# Model: (4, 1, 3)
# Model: (4, 1, 4)

# %%
# Creating an empty Dataframe with column names only
ARIMA_AIC = pd.DataFrame(columns=['param', 'AIC'])
ARIMA_AIC
# Out:
# Empty DataFrame
# Columns: [param, AIC]
# Index: []

# %%
from statsmodels.tsa.arima.model import ARIMA

for param in pdq:# running a loop within the pdq parameters defined by itertools
    ARIMA_model = ARIMA(train['Sparkling'].values,order=param).fit()#fitting the ARIMA model
    #using the parameters from the loop
    print('ARIMA{} - AIC:{}'.format(param,ARIMA_model.aic))#printing the parameters and the AIC
    #from the fitted models
    ARIMA_AIC = ARIMA_AIC.append({'param':param, 'AIC': ARIMA_model.aic}, ignore_index=True)
    #appending the AIC values and the model parameters to the previously created data frame
    #for easier understanding and sorting of the AIC values
# Out:
# ARIMA(0, 1, 0) - AIC:2267.6630357855465
# ARIMA(0, 1, 1) - AIC:2263.060015591336
# ARIMA(0, 1, 2) - AIC:2234.4083231238383
# ARIMA(0, 1, 3) - AIC:2233.9948577518107
# ARIMA(0, 1, 4) - AIC:2235.1737364695036
# ARIMA(1, 1, 0) - AIC:2266.6085393190087
# ARIMA(1, 1, 1) - AIC:2235.755094678081
# ARIMA(1, 1, 2) - AIC:2234.5272004528006
# ARIMA(1, 1, 3) - AIC:2235.607815235513
# ARIMA(1, 1, 4) - AIC:2227.7369771472468
# ARIMA(2, 1, 0) - AIC:2260.36574396809
# ARIMA(2, 1, 1) - AIC:2233.7776263108312
# ARIMA(2, 1, 2) - AIC:2213.5092124003604
# ARIMA(2, 1, 3) - AIC:2232.8904614629228
# ARIMA(2, 1, 4) - AIC:2222.921832387425
# ARIMA(3, 1, 0) - AIC:2257.72337899794
# ARIMA(3, 1, 1) - AIC:2235.4986052031873
# ARIMA(3, 1, 2) - AIC:2230.759495879124
# ARIMA(3, 1, 3) - AIC:2221.459263352943
# ARIMA(3, 1, 4) - AIC:2219.880533250706
# ARIMA(4, 1, 0) - AIC:2259.741841399269
# ARIMA(4, 1, 1) - AIC:2237.073043262142
# ARIMA(4, 1, 2) - AIC:2233.078443285004
# ARIMA(4, 1, 3) - AIC:2222.904098494765
# ...

# %%
ARIMA_least_AIC = ARIMA_AIC.sort_values(by='AIC',ascending=True)
ARIMA_least_AIC.head(2)
# Out:
#         param          AIC
# 12  (2, 1, 2)  2213.509212
# 24  (4, 1, 4)  2213.720952

# %%
## ARIMA(2,1,2) has the lowest AIC
model = ARIMA(train, order=(2,1,2),freq="MS")

results_arima = model.fit()

print(results_arima.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:              Sparkling   No. Observations:                  132
# Model:                 ARIMA(2, 1, 2)   Log Likelihood               -1101.755
# Date:                Mon, 28 Jun 2021   AIC                           2213.509
# Time:                        15:27:51   BIC                           2227.885
# Sample:                    01-01-1980   HQIC                          2219.351
#                          - 12-01-1990
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.3121      0.046     28.782      0.000       1.223       1.401
# ar.L2         -0.5593      0.072     -7.741      0.000      -0.701      -0.418
# ma.L1         -1.9917      0.109    -18.217      0.000      -2.206      -1.777
# ...

# %%
#get prediction start and end dates
pred_start_date = test.index[0]
pred_end_date = test.index[-1]

#get the predictions and residuals
predictions = results_arima.predict(start=pred_start_date, end=pred_end_date)
residuals = test['Sparkling'] - predictions

# %%
ARIMA_RMSE = metrics.mean_squared_error(test['Sparkling'],predictions,squared=False)

print("AutoARIMA Model(least AIC)(2,1,2):, RMSE is %3.2f" 
      %(ARIMA_RMSE))
# Out:
# AutoARIMA Model(least AIC)(2,1,2):, RMSE is 1299.98

# %%
#store the RMSE details in the table
tempResultsDf= pd.DataFrame({'Model': 'AutoARIMA Model(least AIC)(2,1,2)', 'WineType':['Sparkling'],
                              'Test_RMSE': ARIMA_RMSE})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# ## SARIMA Model

# %%
import itertools
p = q = range(0,4)
P = Q = range(0,3)
d = range(1,2)
D = range(0,2)
pdq = list(itertools.product(p, d, q))
model_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(P, D, Q))]

# %%
SARIMA_AIC = pd.DataFrame(columns=['param','seasonal', 'AIC'])
SARIMA_AIC
# Out:
# Empty DataFrame
# Columns: [param, seasonal, AIC]
# Index: []

# %%
import statsmodels.api as sm

for param in pdq:
    for param_seasonal in model_pdq:
        SARIMA_model = sm.tsa.statespace.SARIMAX(train,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
            
        results_SARIMA = SARIMA_model.fit()
        print('SARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results_SARIMA.aic))
        SARIMA_AIC = SARIMA_AIC.append({'param':param,'seasonal':param_seasonal ,'AIC': results_SARIMA.aic}, ignore_index=True)
# Out:
# SARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:2251.3597196862966
# SARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:1956.2614616847052
# SARIMA(0, 1, 0)x(0, 0, 2, 12)12 - AIC:1723.1533640236594
# SARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:1822.9824851895298
# SARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:1626.862633467847
# SARIMA(0, 1, 0)x(0, 1, 2, 12)12 - AIC:1452.6773574251765
# SARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:1837.4366022456675
# SARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:1806.9905301388558
# SARIMA(0, 1, 0)x(1, 0, 2, 12)12 - AIC:1633.2108735792106
# SARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:1646.3778167661442
# SARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:1628.3243908188433
# SARIMA(0, 1, 0)x(1, 1, 2, 12)12 - AIC:1454.528962130725
# SARIMA(0, 1, 0)x(2, 0, 0, 12)12 - AIC:1648.3776153470858
# SARIMA(0, 1, 0)x(2, 0, 1, 12)12 - AIC:1647.20541586036
# SARIMA(0, 1, 0)x(2, 0, 2, 12)12 - AIC:1630.989805392077
# SARIMA(0, 1, 0)x(2, 1, 0, 12)12 - AIC:1466.6211360755017
# SARIMA(0, 1, 0)x(2, 1, 1, 12)12 - AIC:1468.5000981866713
# ...

# %%
SARIMA_AIC.sort_values(by=['AIC']).head(2)
# Out:
#          param       seasonal          AIC
# 203  (2, 1, 3)  (0, 1, 2, 12)  1368.143158
# 209  (2, 1, 3)  (1, 1, 2, 12)  1369.790947

# %%
import statsmodels.api as sm

model = sm.tsa.statespace.SARIMAX(train['Sparkling'].values,
                                order=(2, 1, 3),
                                seasonal_order=(0, 1, 2, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results_SARIMA = model.fit()
print(results_SARIMA.summary())
# Out:
#                                         SARIMAX Results
# ...
# Dep. Variable:                                       y   No. Observations:                  132
# Model:             SARIMAX(2, 1, 3)x(0, 1, [1, 2], 12)   Log Likelihood                -676.072
# Date:                                 Mon, 28 Jun 2021   AIC                           1368.143
# Time:                                         15:32:39   BIC                           1388.230
# Sample:                                              0   HQIC                          1376.247
#                                                  - 132
# Covariance Type:                                   opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.7031      0.132    -12.894      0.000      -1.962      -1.444
# ar.L2         -0.7224      0.134     -5.397      0.000      -0.985      -0.460
# ...

# %%
#get the predictions and residuals
predictions = results_SARIMA.get_forecast(steps=len(test))

# %%
SARIMA_RMSE = metrics.mean_squared_error(test['Sparkling'],predictions.predicted_mean,squared=False)

print("AutoSARIMA Model(least AIC)(2,1,3)(0,1,2,12):, RMSE is %3.2f" 
      %(SARIMA_RMSE))
# Out:
# AutoSARIMA Model(least AIC)(2,1,3)(0,1,2,12):, RMSE is 413.62

# %%
#store the RMSE details in the table
tempResultsDf= pd.DataFrame({'Model': 'AutoSARIMA Model(least AIC)(2,1,3)(0,1,2,12)', 'WineType':['Sparkling'],
                              'Test_RMSE': SARIMA_RMSE})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# # Model 14 & 15: ARIMA & SARIMA models based on the cut-off points of ACF & PACF

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
from matplotlib.pyplot import figure
import statsmodels.api as sm
import statsmodels.tsa.api as smt
import statsmodels.formula.api as smf

# %% [markdown]
# ## ACF & PACF

# %% [markdown]
# A nonseasonal ARIMA model is classified as an "ARIMA(p,d,q)" model, where:
#
# - p is the number of autoregressive terms,
# - d is the number of nonseasonal differences needed for stationarity, and
# - q is the number of lagged forecast errors in the prediction equation.
#
# Now, the question is how to find out these values based on ACF and PACF graph.

# %% [markdown]
# ### Original Series

# %%
# ACF and PACF with original time series
fig, axes = plt.subplots(1, 2)
fig.set_figwidth(12)
fig.set_figheight(4)
smt.graphics.plot_acf(train, lags=50, ax=axes[0],
                      title='Sparkling Wine: Autocorrelation')
smt.graphics.plot_pacf(train, lags=50, ax=axes[1],
                       title='Sparkling Wine: Partial Autocorrelation')
plt.tight_layout()

# %% [markdown]
# Here, we could see very less PACF and ACF has significant correlation at lag 1 but after that it is decaying and becoming insignificant.
#
# Hence, try differencing the order using d = 1 and try to evaluate ACF and PACF again.

# %% [markdown]
# ### Differenced Time series with (d = 1)

# %%
# ACF with order difference as "1" as the series was not stationary (refer stationary point#5)
fig, axes = plt.subplots(1, 2)
fig.set_figwidth(12)
fig.set_figheight(4)
smt.graphics.plot_acf(train.diff().dropna(), lags=15, ax=axes[0],
                      title='Sparkling Wine: Differenced Series Autocorrelation (ACF)')
smt.graphics.plot_pacf(train.diff().dropna(), lags=15, ax=axes[1],
                       title='Sparkling Wine: Differenced Series Partial Autocorrelation (PACF)')
plt.tight_layout()

# %% [markdown]
# ## ARIMA Model

# %% [markdown]
# Based on graph, let's evaluate p and q value.
#
# Here, we have taken alpha=0.05.
#
# - The Auto-Regressive parameter in an ARIMA model is 'p' which comes from the significant lag before which the PACF plot cuts-off to 0.
# - The Moving-Average parameter in an ARIMA model is 'q' which comes from the significant lag before the ACF plot cuts-off to 0.
#
# By looking at the above plots, we will take the value of p and q to be 1.
#
# __Hence, let's take ACF(q)(MA) value as 1 and PACF(p)(AR) value as 1__

# %%
# p = 1 , d = 1 and q = 1

# %% [markdown]
# ### ARIMA(1,1,1)

# %%
model_manual = ARIMA(train, order=(1,1,1),freq="MS")

results_manual_arima = model_manual.fit()

print(results_manual_arima.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:              Sparkling   No. Observations:                  132
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -1114.878
# Date:                Mon, 28 Jun 2021   AIC                           2235.755
# Time:                        15:32:41   BIC                           2244.381
# Sample:                    01-01-1980   HQIC                          2239.260
#                          - 12-01-1990
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4494      0.043     10.366      0.000       0.364       0.534
# ma.L1         -0.9996      0.102     -9.811      0.000      -1.199      -0.800
# sigma2      1.401e+06   7.57e-08   1.85e+13      0.000     1.4e+06     1.4e+06
# ...

# %% [markdown]
# Here we could see two main things:
#
# - P values at all lags are significant (i.e. P value is less then 0.05)
#
# Hence, ARIMA (1,1,1) is On the whole, this appears to be a good model.

# %%
#get prediction start and end dates
pred_start_date = test.index[0]
pred_end_date = test.index[-1]

#get the predictions and residuals
predictions = results_manual_arima.predict(start=pred_start_date, end=pred_end_date)
residuals = test['Sparkling'] - predictions

# %%
ARIMA_Manual_RMSE = metrics.mean_squared_error(test['Sparkling'],predictions,squared=False)

print("ManualARIMA Model(ACF-PACF)(1,1,1):, RMSE is %3.2f" 
      %(ARIMA_Manual_RMSE))
# Out:
# ManualARIMA Model(ACF-PACF)(1,1,1):, RMSE is 1319.94

# %%
#store the RMSE details in the table
tempResultsDf= pd.DataFrame({'Model': 'ManualARIMA Model(ACF-PACF)(1,1,1)', 'WineType':['Sparkling'],
                              'Test_RMSE': ARIMA_Manual_RMSE})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# ### SARIMA Model

# %% [markdown]
# Let's have a look on the ACF and the PACF plots one more time.

# %% [markdown]
# #### ACF and PACF (differenced d = 1)

# %%
fig, axes = plt.subplots(1, 2)
fig.set_figwidth(12)
fig.set_figheight(4)
smt.graphics.plot_acf(train.diff().dropna(), lags=50, ax=axes[0],
                      title='Sparkling Wine: Differenced Series Autocorrelation (ACF)')
smt.graphics.plot_pacf(train.diff().dropna(), lags=50, ax=axes[1],
                       title='Sparkling Wine: Differenced Series Partial Autocorrelation (PACF)')
plt.tight_layout()

# %% [markdown]
# We could see that ACF plot at the seasonal interval (i.e. 12) does not taper off. So, now we take a seasonal differencing and check the series

# %% [markdown]
# #### ACF and PACF Seasonal differece(12)

# %%
(train.diff(12)).plot(figsize=(14,6))
plt.grid();

# %% [markdown]
# We see that there might be a slight trend which can be noticed in the data. So we take a differencing of first order on the seasonally differenced series.

# %% [markdown]
# Let us go ahead and check the stationarity of the above series before fitting the SARIMA model.

# %%
dftest = adfuller(train.diff(12).dropna(),regression='ct')
print('DF test statistic is %3.3f' %dftest[0])
print('DF test p-value is' ,dftest[1])
print('Number of lags used' ,dftest[2])
# Out:
# DF test statistic is -8.458
# DF test p-value is 6.266010697306863e-12
# Number of lags used 0

# %% [markdown]
# The series is stationary. Let's check the ACF and the PACF plots for the new modified Time Series.

# %%
# ACF with seasonal difference as "12"
fig, axes = plt.subplots(1, 2)
fig.set_figwidth(12)
fig.set_figheight(4)
smt.graphics.plot_acf(train.diff(12).dropna(), lags=20, ax=axes[0],
                      title='Sparkling Wine: Seasonal Diff(12) Series ACF')
smt.graphics.plot_pacf(train.diff(12).dropna(), lags=20, ax=axes[1],
                       title='Sparkling Wine: Seasonal Diff(12) Series PACF')
plt.tight_layout()

# %% [markdown]
# Here, we have taken alpha=0.05.
#
# We are going to take the seasonal period as 12.
# We will keep the p(2) and q(2) parameters same as the ARIMA model.
#
# - The Auto-Regressive parameter in an SARIMA model is 'P' which comes from the significant lag after which the PACF plot cuts-off to 0.
# - The Moving-Average parameter in an SARIMA model is 'Q' which comes from the significant lag after which the ACF plot cuts-off to 0.
#
# Remember to check the ACF and the PACF plots only at multiples of 12 (since 12 is the seasonal period).
#
# By looking at the plots we see that both the ACF and the PACF cuts-off after lag 1. Remember, here we are considering the seasonal lags.

# %%
# p = 1, d = 1, q = 1
# P = 1, D = 1, Q = 1 F = 12

# %%
manual_SARIMA = sm.tsa.statespace.SARIMAX(train,
                                order=(1, 1, 1),
                                seasonal_order=(1, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results_manual_SARIMA = manual_SARIMA.fit()
print(results_manual_SARIMA.summary())
# Out:
#                                      SARIMAX Results
# ...
# Dep. Variable:                          Sparkling   No. Observations:                  132
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood                -780.336
# Date:                            Mon, 28 Jun 2021   AIC                           1570.672
# Time:                                    15:32:42   BIC                           1583.942
# Sample:                                01-01-1980   HQIC                          1576.050
#                                      - 12-01-1990
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1662      0.120      1.388      0.165      -0.068       0.401
# ma.L1         -0.9398      0.057    -16.511      0.000      -1.051      -0.828
# ...

# %%
#get prediction start and end dates
pred_start_date = test.index[0]
pred_end_date = test.index[-1]

#get the predictions and residuals
predictions = results_manual_SARIMA.predict(start=pred_start_date, end=pred_end_date)
residuals = test['Sparkling'] - predictions

# %%
SARIMA_Manual_RMSE = metrics.mean_squared_error(test['Sparkling'],predictions,squared=False)

print("ManualSARIMA Model(ACF-PACF)(1,1,1)(1,1,1,12):, RMSE is %3.2f" 
      %(SARIMA_Manual_RMSE))
# Out:
# ManualSARIMA Model(ACF-PACF)(1,1,1)(1,1,1,12):, RMSE is 375.61

# %%
#store the RMSE details in the table
tempResultsDf= pd.DataFrame({'Model': 'ManualSARIMA Model(ACF-PACF)(1,1,1)(1,1,1,12)', 'WineType':['Sparkling'],
                              'Test_RMSE': SARIMA_Manual_RMSE})
resultsDf= pd.concat([resultsDf, tempResultsDf]).sort_values(by='WineType').sort_values(by='Test_RMSE')

# %% [markdown]
# # Table with All Models
# __(corresponding parameters and test RMSE value)__

# %% [markdown]
# At the time of model creation and evaluation we have stored model details with its parameters, type of wine and test RMSE value

# %%
# this is the final table which has all the model stored with sorted with least RMSE value.
resultsDf
# Out:
#                                            Model   WineType    Test_RMSE
# 0  ManualSARIMA Model(ACF-PACF)(1,1,1)(1,1,1,12)  Sparkling   375.614013
# 0   AutoSARIMA Model(least AIC)(2,1,3)(0,1,2,12)  Sparkling   413.620023
# 0                       RegressionOnTimeSeasonal  Sparkling   427.472000
# 0     TES(Holt_Winter)-Mul(L:0.11,T:0.06,S:0.39)  Sparkling   469.432003
# 0     TES(Holt_Winter)-Add(L:0.11,T:0.04,S:0.49)  Sparkling   473.954411
# 0                          moving_avg_forecast_3  Sparkling  1028.606000
# 0                          moving_avg_forecast_4  Sparkling  1156.590000
# 0                          moving_avg_forecast_5  Sparkling  1234.045000
# 0                         moving_avg_forecast_12  Sparkling  1267.925000
# 0                 DES(least RMSE)(L:0.02,T:0.50)  Sparkling  1274.630824
# 0                                 Simple Average  Sparkling  1275.082000
# 0                        SES(least RMSE)(L:0.02)  Sparkling  1279.495201
# ...

# %% [markdown]
# Around total of 15 models we have build for "Sparkling Wine" dataset and the best model which is coming out is
#
# __SARIMA Model (ACF and PACF) with parameters (p=1,d=1,q=1)(P=1,D=1,Q=1,F=12) and test RMSE value ~376__
#
# Now, we will take this model and forecast 12 months into the future with appropriate confidence intervals to see how the predictions look. We have to build our model on the full data for this.

# %% [markdown]
# # Run the best model (Manual SARIMA) on full dataset and predict 12 months into the future with appropriate confidence intervals/bands

# %% [markdown]
# Here, we have both training and full data both were non-stationary hence, nothing to be done in terms of stationarity.

# %% [markdown]
# ## Run best model with fulldata

# %%
model_fulldata = sm.tsa.statespace.SARIMAX(df,
                                order=(1,1,1),
                                seasonal_order=(1, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results_model_fulldata = model_fulldata.fit()
print(results_model_fulldata.summary())
# Out:
#                                      SARIMAX Results
# ...
# Dep. Variable:                          Sparkling   No. Observations:                  187
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood               -1180.382
# Date:                            Mon, 28 Jun 2021   AIC                           2370.765
# Time:                                    15:32:43   BIC                           2386.141
# Sample:                                01-01-1980   HQIC                          2377.009
#                                      - 07-01-1995
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1151      0.082      1.398      0.162      -0.046       0.276
# ma.L1         -0.9655      0.033    -29.501      0.000      -1.030      -0.901
# ...

# %%
results_model_fulldata.plot_diagnostics();

# %% [markdown]
# ## Forcast for next 12 months with confidence intervals

# %%
prediction_nxt12mnths = results_model_fulldata.get_forecast(steps=12)

# %%
prediction_nxt12mnths.summary_frame(alpha=0.05)
# Out:
# Sparkling          mean     mean_se  mean_ci_lower  mean_ci_upper
# 1995-08-01  1946.522299  384.306578    1193.295246    2699.749352
# 1995-09-01  2417.781910  388.581362    1656.176435    3179.387384
# 1995-10-01  3292.400711  389.089260    2529.799774    4055.001647
# 1995-11-01  3950.757308  389.399739    3187.547845    4713.966772
# 1995-12-01  6151.543256  389.690425    5387.764058    6915.322453
# 1996-01-01  1238.842795  389.978688     474.498611    2003.186979
# 1996-02-01  1613.898807  390.266484     848.990554    2378.807061
# 1996-03-01  1828.004545  390.554039    1062.532695    2593.476394
# 1996-04-01  1820.785331  390.841378    1054.750306    2586.820356
# 1996-05-01  1670.366615  391.128506     903.768830    2436.964400
# 1996-06-01  1622.236282  391.415423     855.076150    2389.396415
# 1996-07-01  2018.270769  391.702130    1250.548700    2785.992837

# %%
RMSE_fulldata = metrics.mean_squared_error(df['Sparkling'],results_model_fulldata.fittedvalues,squared=False)

print("ManualSARIMA Model(ACF-PACF)(1,1,1)(1,1,1,12):, RMSE is %3.2f" 
      %(RMSE_fulldata))
# Out:
# ManualSARIMA Model(ACF-PACF)(1,1,1)(1,1,1,12):, RMSE is 544.98

# %%
pred_full_manual_SARIMA_date = prediction_nxt12mnths.summary_frame(alpha=0.05).set_index(pd.date_range(start='1995-08-01',end='1996-07-01', freq='MS'))

# %%
# plot the forecast along with the confidence band

axis = df['Sparkling'].plot(label='Actual')
pred_full_manual_SARIMA_date['mean'].plot(ax=axis, label='Forecast', alpha=0.7,figsize=(20,6))
axis.fill_between(pred_full_manual_SARIMA_date.index, pred_full_manual_SARIMA_date['mean_ci_lower'], 
                  pred_full_manual_SARIMA_date['mean_ci_upper'], color='black', alpha=.15)
axis.set_xlabel('Year-Months')
axis.set_ylabel('Sales: Sparkling Wine')
plt.legend(loc='best')
plt.grid();

# %% [markdown]
# # Comment on the model thus built and report your findings and suggest the measures that the company should be taking for future sales

# %% [markdown]
# ## Key Findings:

# %% [markdown]
# __Plot diagnostics summary charts__ gives promising result and below are point that justifies the same.
#
# - (Top left chart): Residual chart says it is ranges between 4 to -2 which is good. The residuals over time don't display any obvious seasonality and appear to be white noise.
#
# - (Bottom right chart): This is confirmed by the autocorrelation (i.e. correlogram) plot, which shows that the time series residuals have low correlation with lagged versions of itself. Autocorrelation (correlogram) plot of the residuals doesn't show the unexplained correlation which is left in the data.
#
# - (Bottom left chart): QQ (Normaluity) plot have the linear relationship. Further, it shows that the ordered distribution of residuals (blue dots) follows the linear trend of the samples taken from a standard normal distribution with N(0, 1). Again, this is a strong indication that the residuals are normally distributed.
#
# - (Top right chart): Distribution plot is seems to be normal with mean 0 and std as 1 with in no real outliers.
#
# So, Overall we can conclude that that residuals are random with no information or juice in them and our model produces a satisfactory fit that could help us understand our time series data and forecast future values.

# %% [markdown]
# ## Business Recommendations:

# %% [markdown]
# Time series forecasting helps businesses make informed business decisions because it can be based on historical data patterns. It can be used to forecast future conditions and events. mentioned below are four key characteristics which time series forecasting has.
#
# __Reliability:__ Time series forecasting is most reliable, especially when the data represents a broad time period such as large numbers of observations for longer time periods. Information can be extracted by measuring data at various intervals.
#
# __Seasonal patterns:__ Data points variances measured can reveal seasonal fluctuation patterns that serve as the basis for forecasts. Such information is of particular importance to markets whose products fluctuate seasonally because it helps them plan for production and delivery requirements.
#
# __Trend estimation:__ Time series method can also be used to identify trends because data tendencies from it can be useful to managers when measurements show a decrease or an increase in sales for a particular product.
#
# __Growth:__ Time series method is useful to measure both endogenous and financial growth. Endogenous growth is the development from within an organization’s internal human capital that leads to economic growth. For example, the impact of policy variables can be evidenced through time series analysis.
#
# Based on the Sparkling Wine dataset, it is coming out that this timeseries has __almost no trend, high seasonality(~95% of the volume is happening in the month of November and December){hence, median sales across the years doesn't have any changes but monthwise it is giving major impact}__.
#
# According to us, mentioned below are the __ways through which we could manage the business seasonality__.
#
# - Look for ways to diversify: e can offset seasonality by being as innovative as possible. Whether that means diversifying product lines or by pre-empting what your customers want. Market survery is the best way to understand the business/customer needs.
#
# - Develop sales, inventory and staffing plans: Planning inventory and sales at least six months ahead will helps pinpoint where business needs to build in a cash cushion to tide over during quieter periods. Plan everything from stock levels to staff. That way business have the supplies and all material required when demand picks up again. A cash flow forecast can also help with this.
#
# - Think ahead, how will this new seasonal business develop? Will it simply become an addition to your current business, or has it got strong enough legs to stand on its own?
